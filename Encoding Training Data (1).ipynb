# %% [markdown]
# Encoding Training Data using Model VII for OCNN

# %%
from keras.models import load_model
import numpy as np
# Out:
# Using TensorFlow backend.

# %%
cd drive/My\ Drive/concrete_crack
# Out:
# /content/drive/My Drive/concrete_crack

# %%
cd data_64/
# Out:
# /content/drive/My Drive/concrete_crack/data_64

# %%
X_train = np.load('X_train.npy', allow_pickle=True)

# %%
cd ..
# Out:
# /content/drive/My Drive/concrete_crack

# %%
cd model7/
# Out:
# /content/drive/My Drive/concrete_crack/model7

# %%
encoder = load_model('encoder.h5')
# Out:
# /usr/local/lib/python3.6/dist-packages/keras/engine/saving.py:341: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '

# %%
encoded_data = encoder.predict(X_train)

# %%
encoded_data.shape
# Out:
# (16000, 128)

# %%
pwd
# Out:
# '/content/drive/My Drive/concrete_crack/model7'

# %%
cd ..
# Out:
# /content/drive/My Drive/concrete_crack

# %%
cd data_64/
# Out:
# /content/drive/My Drive/concrete_crack/data_64

# %%
np.save('X_train_encoded', encoded_data, allow_pickle=True)
