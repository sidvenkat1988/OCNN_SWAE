# %%
cd drive/My\ Drive/concrete_crack
# Out:
# /content/drive/My Drive/concrete_crack

# %%
import numpy as np
import keras.utils
from keras.layers import Input, Dense, Flatten
from keras.models import load_model, Model
from keras.layers import Conv2D, UpSampling2D, AveragePooling2D
from keras.layers import LeakyReLU, Reshape
from keras.models import save_model
from keras import backend as K
import tensorflow as tf
import matplotlib.pyplot as plt
from IPython import display
from sklearn.datasets import make_circles
import time
# Out:
# Using TensorFlow backend.

# %%
import os

# %%
def generateTheta(L, endim):
  samples = np.random.uniform(size = (L, endim))
  theta = [w/np.sqrt((w**2).sum()) for w in samples]
  return np.asarray(theta)

def generateZ(batchsize):
  temp = make_circles(2*batchsize, noise = 0.1)
  zeroth_index = np.where(temp[1] == 0)[0]
  temp_zero_values = temp[0][zeroth_index]
  return np.array(temp_zero_values)

# %%
L = 50
batchsize = 100
endim = 2

# %%
img = Input(shape = (28,28,1))
x = Conv2D(16, (3,3), padding = 'same')(img)
x = LeakyReLU(alpha = 0.2)(x)
x = Conv2D(16, (3,3), padding = 'same')(x)
x = LeakyReLU(alpha = 0.2)(x)
x = AveragePooling2D((2,2), padding = 'same')(x) #(none, 14, 14, 16)

x = Conv2D(32, (3,3), padding = 'same')(x)
x = LeakyReLU(alpha = 0.2)(x)
x = Conv2D(32, (3,3), padding = 'same')(x)
x = LeakyReLU(alpha = 0.2)(x)
x = AveragePooling2D((2,2), padding = 'same')(x) #(none, 7, 7, 32)

x = Conv2D(64, (3,3), padding = 'same')(x)
x = LeakyReLU(alpha = 0.2)(x)
x = Conv2D(64, (3,3), padding = 'same')(x)
x = LeakyReLU(alpha = 0.2)(x)
x = AveragePooling2D((2,2), padding = 'same')(x) #(none, 4, 4, 64)

x = Flatten()(x) #(none, 4*4*64)
x = Dense(128, activation = 'relu')(x)
encoded = Dense(endim)(x)

encoder = Model(inputs = [img], outputs = [encoded])
encoder.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 28, 28, 1)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 28, 28, 16)        160
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 28, 28, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 28, 28, 16)        2320
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 28, 28, 16)        0
# _________________________________________________________________
# average_pooling2d_1 (Average (None, 14, 14, 16)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 14, 14, 32)        4640
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 14, 14, 32)        9248
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 14, 14, 32)        0
# _________________________________________________________________
# average_pooling2d_2 (Average (None, 7, 7, 32)          0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 7, 7, 64)          18496
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 7, 7, 64)          0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 7, 7, 64)          36928
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 7, 7, 64)          0
# _________________________________________________________________
# average_pooling2d_3 (Average (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               131200
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 258
# =================================================================
# Total params: 203,250
# Trainable params: 203,250
# Non-trainable params: 0
# _________________________________________________________________

# %%
embedd = Input(shape = (endim, ))
x = Dense(128)(embedd)
x = Dense(4*4*64, activation = 'relu')(x)
x = Reshape((4,4,64))(x)
x = UpSampling2D((2,2))(x) #(none, 8, 8, 64)

x = Conv2D(64, (3,3), padding='same')(x)
x = LeakyReLU(alpha = 0.2)(x)
x = Conv2D(64, (3,3), padding = 'same')(x)
x = LeakyReLU(alpha = 0.2)(x)
x = UpSampling2D((2,2))(x) #(none, 16, 16, 64)

x = Conv2D(64, (3,3), padding = 'valid')(x)
x = LeakyReLU(alpha = 0.2)(x)
x = Conv2D(64, (3,3), padding = 'same')(x)
x = LeakyReLU(alpha = 0.2)(x)
x = UpSampling2D((2,2))(x) #(none, 28, 28, 64)

x = Conv2D(32, (3,3), padding = 'same')(x)
x = LeakyReLU(alpha = 0.2)(x)
x = Conv2D(32, (3,3), padding = 'same')(x)
x = LeakyReLU(alpha = 0.2)(x)
decoded = Conv2D(1, (3,3), padding = 'same', activation = 'sigmoid')(x)

decoder = Model(inputs = [embedd], outputs = [decoded])
decoder.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 2)                 0
# _________________________________________________________________
# dense_3 (Dense)              (None, 128)               384
# _________________________________________________________________
# dense_4 (Dense)              (None, 1024)              132096
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 4, 4, 64)          0
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 8, 8, 64)          36928
# _________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)    (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 8, 8, 64)          36928
# _________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)    (None, 8, 8, 64)          0
# _________________________________________________________________
# up_sampling2d_2 (UpSampling2 (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 14, 14, 64)        36928
# _________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)    (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 14, 14, 64)        36928
# _________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)   (None, 14, 14, 64)        0
# _________________________________________________________________
# up_sampling2d_3 (UpSampling2 (None, 28, 28, 64)        0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 28, 28, 32)        18464
# _________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)   (None, 28, 28, 32)        0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 28, 28, 32)        9248
# _________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)   (None, 28, 28, 32)        0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 28, 28, 1)         289
# =================================================================
# Total params: 308,193
# Trainable params: 308,193
# Non-trainable params: 0
# _________________________________________________________________

# %%
theta = K.variable(generateTheta(L, endim))
z = K.variable(generateZ(batchsize))

# %%
encoded_image = encoder(img)
decoded_image = decoder(encoded_image)
autoencoder = Model(inputs = [img], outputs = [decoded_image])
autoencoder.summary()
# Out:
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 28, 28, 1)         0
# _________________________________________________________________
# model_1 (Model)              (None, 2)                 203250
# _________________________________________________________________
# model_2 (Model)              (None, 28, 28, 1)         308193
# =================================================================
# Total params: 511,443
# Trainable params: 511,443
# Non-trainable params: 0
# _________________________________________________________________

# %%
proj_encoded = K.dot(encoded_image, K.transpose(theta))
proj_z = K.dot(z, K.transpose(theta))

# %%
proj_encoded_transpose = tf.nn.top_k(tf.transpose(proj_encoded), k = batchsize).values
proj_z_transpose = tf.nn.top_k(tf.transpose(proj_z), k = batchsize).values

# %%
w2 = (proj_encoded_transpose - proj_z_transpose)**2
w2weight = K.variable(10.0)
w2loss = w2weight * K.mean(w2)

# %%
crossEntropy = K.binary_crossentropy(K.flatten(img), K.flatten(decoded_image))
crossEntropyLoss = 1.0 * K.mean(crossEntropy)

# %%
absolute_difference = K.abs(K.flatten(img) - K.flatten(decoded_image))
L1Loss = 1.0 * K.mean(absolute_difference)

# %%
total_loss = w2loss + crossEntropyLoss + L1Loss

# %%
autoencoder.add_loss(total_loss)
autoencoder.compile(optimizer = 'rmsprop', loss = '')
# Out:
# /usr/local/lib/python3.6/dist-packages/keras/engine/training_utils.py:819: UserWarning: Output model_2 missing from loss dictionary. We assume this was done on purpose. The fit and evaluate APIs will not be expecting any data to be passed to model_2.
#   'be expecting any data to be passed to {0}.'.format(name))

# %%
cd data_28
# Out:
# /content/drive/My Drive/concrete_crack/data_28

# %%
X_train = np.load('X_train.npy', allow_pickle=True)

# %%
history = autoencoder.fit(X_train, None, validation_split=0.2, epochs = 100, batch_size = 100)
# Out:
# Train on 12800 samples, validate on 3200 samples
# Epoch 1/100
# 12800/12800 [==============================] - 12s 952us/step - loss: 5.6898 - val_loss: 4.6326
# Epoch 2/100
# 12800/12800 [==============================] - 7s 537us/step - loss: 4.1603 - val_loss: 5.2722
# Epoch 3/100
# 12800/12800 [==============================] - 7s 537us/step - loss: 3.3056 - val_loss: 1.9932
# Epoch 4/100
# 12800/12800 [==============================] - 7s 532us/step - loss: 2.7689 - val_loss: 2.3824
# Epoch 5/100
# 12800/12800 [==============================] - 7s 537us/step - loss: 2.4143 - val_loss: 2.5380
# Epoch 6/100
# 12800/12800 [==============================] - 7s 537us/step - loss: 2.1217 - val_loss: 1.6720
# Epoch 7/100
# 12800/12800 [==============================] - 7s 540us/step - loss: 1.9861 - val_loss: 2.8278
# Epoch 8/100
# 12800/12800 [==============================] - 7s 533us/step - loss: 1.8263 - val_loss: 1.3905
# Epoch 9/100
# 12800/12800 [==============================] - 7s 536us/step - loss: 1.7880 - val_loss: 1.2752
# Epoch 10/100
# 12800/12800 [==============================] - 7s 534us/step - loss: 1.7023 - val_loss: 1.2728
# Epoch 11/100
# 12800/12800 [==============================] - 7s 534us/step - loss: 1.5914 - val_loss: 1.8244
# Epoch 12/100
# 12800/12800 [==============================] - 7s 528us/step - loss: 1.4649 - val_loss: 1.2650
# Epoch 13/100
# 12800/12800 [==============================] - 7s 536us/step - loss: 1.4590 - val_loss: 1.5651
# Epoch 14/100
# 12800/12800 [==============================] - 7s 534us/step - loss: 1.3050 - val_loss: 0.7918
# Epoch 15/100
# 12800/12800 [==============================] - 7s 535us/step - loss: 1.1352 - val_loss: 0.7935
# Epoch 16/100
# 12800/12800 [==============================] - 7s 535us/step - loss: 1.0418 - val_loss: 0.9430
# Epoch 17/100
# 12800/12800 [==============================] - 7s 537us/step - loss: 1.0974 - val_loss: 1.0060
# Epoch 18/100
# 12800/12800 [==============================] - 7s 537us/step - loss: 1.0082 - val_loss: 0.7780
# Epoch 19/100
# 12800/12800 [==============================] - 7s 535us/step - loss: 1.0334 - val_loss: 1.0009
# Epoch 20/100
# 12800/12800 [==============================] - 7s 535us/step - loss: 0.9712 - val_loss: 0.7820
# Epoch 21/100
# 12800/12800 [==============================] - 7s 536us/step - loss: 0.9465 - val_loss: 1.0692
# Epoch 22/100
# 12800/12800 [==============================] - 7s 539us/step - loss: 0.9655 - val_loss: 0.9323
# Epoch 23/100
# 12800/12800 [==============================] - 7s 539us/step - loss: 0.9285 - val_loss: 0.7759
# Epoch 24/100
# 12800/12800 [==============================] - 7s 537us/step - loss: 0.9204 - val_loss: 0.7481
# Epoch 25/100
# 12800/12800 [==============================] - 7s 535us/step - loss: 0.8947 - val_loss: 1.0481
# Epoch 26/100
# 12800/12800 [==============================] - 7s 535us/step - loss: 0.9333 - val_loss: 0.7471
# Epoch 27/100
# 12800/12800 [==============================] - 7s 537us/step - loss: 0.9240 - val_loss: 0.8928
# Epoch 28/100
# 12800/12800 [==============================] - 7s 539us/step - loss: 0.8737 - val_loss: 0.7483
# Epoch 29/100
# 12800/12800 [==============================] - 7s 535us/step - loss: 0.8956 - val_loss: 0.7420
# Epoch 30/100
# 12800/12800 [==============================] - 7s 533us/step - loss: 0.8849 - val_loss: 0.7312
# Epoch 31/100
# 12800/12800 [==============================] - 7s 536us/step - loss: 0.9490 - val_loss: 0.8279
# Epoch 32/100
# 12800/12800 [==============================] - 7s 539us/step - loss: 0.8868 - val_loss: 0.7912
# Epoch 33/100
# 12800/12800 [==============================] - 7s 539us/step - loss: 0.9144 - val_loss: 0.7401
# Epoch 34/100
# 12800/12800 [==============================] - 7s 536us/step - loss: 0.9263 - val_loss: 0.8140
# Epoch 35/100
# 12800/12800 [==============================] - 7s 535us/step - loss: 0.8684 - val_loss: 0.7654
# Epoch 36/100
# 12800/12800 [==============================] - 7s 540us/step - loss: 0.8750 - val_loss: 0.8308
# Epoch 37/100
# 12800/12800 [==============================] - 7s 534us/step - loss: 0.9087 - val_loss: 0.7979
# Epoch 38/100
# 12800/12800 [==============================] - 7s 535us/step - loss: 0.8664 - val_loss: 0.7638
# Epoch 39/100
# 12800/12800 [==============================] - 7s 536us/step - loss: 0.8749 - val_loss: 0.7865
# Epoch 40/100
# 12800/12800 [==============================] - 7s 538us/step - loss: 0.8521 - val_loss: 0.7864
# Epoch 41/100
# 12800/12800 [==============================] - 7s 539us/step - loss: 0.8370 - val_loss: 0.7531
# Epoch 42/100
# 12800/12800 [==============================] - 7s 535us/step - loss: 0.8640 - val_loss: 0.7344
# Epoch 43/100
# 12800/12800 [==============================] - 7s 526us/step - loss: 0.8253 - val_loss: 0.7877
# Epoch 44/100
# 12800/12800 [==============================] - 7s 532us/step - loss: 0.8522 - val_loss: 3.0819
# Epoch 45/100
# 12800/12800 [==============================] - 7s 535us/step - loss: 0.8544 - val_loss: 0.8018
# Epoch 46/100
# 12800/12800 [==============================] - 7s 535us/step - loss: 0.8605 - val_loss: 0.7729
# Epoch 47/100
# 12800/12800 [==============================] - 7s 535us/step - loss: 0.8298 - val_loss: 0.9210
# Epoch 48/100
# 12800/12800 [==============================] - 7s 534us/step - loss: 0.8501 - val_loss: 0.8145
# Epoch 49/100
# 12800/12800 [==============================] - 7s 534us/step - loss: 0.8265 - val_loss: 0.7714
# Epoch 50/100
# 12800/12800 [==============================] - 7s 531us/step - loss: 0.8482 - val_loss: 0.7155
# Epoch 51/100
# 12800/12800 [==============================] - 7s 534us/step - loss: 0.8417 - val_loss: 1.2125
# Epoch 52/100
# 12800/12800 [==============================] - 7s 532us/step - loss: 0.8139 - val_loss: 0.8170
# Epoch 53/100
# 12800/12800 [==============================] - 7s 534us/step - loss: 0.8158 - val_loss: 0.7323
# Epoch 54/100
# 12800/12800 [==============================] - 7s 534us/step - loss: 0.8495 - val_loss: 0.7462
# Epoch 55/100
# 12800/12800 [==============================] - 7s 534us/step - loss: 0.8213 - val_loss: 0.7979
# Epoch 56/100
# 12800/12800 [==============================] - 7s 535us/step - loss: 0.8630 - val_loss: 0.7601
# Epoch 57/100
# 12800/12800 [==============================] - 7s 535us/step - loss: 0.8201 - val_loss: 0.8294
# Epoch 58/100
# 12800/12800 [==============================] - 7s 537us/step - loss: 0.8241 - val_loss: 0.9268
# Epoch 59/100
# 12800/12800 [==============================] - 7s 536us/step - loss: 0.8170 - val_loss: 0.7552
# Epoch 60/100
# 12800/12800 [==============================] - 7s 534us/step - loss: 0.8035 - val_loss: 0.8087
# Epoch 61/100
# 12800/12800 [==============================] - 7s 533us/step - loss: 0.8446 - val_loss: 0.7799
# Epoch 62/100
# 12800/12800 [==============================] - 7s 537us/step - loss: 0.8335 - val_loss: 0.7438
# Epoch 63/100
# 12800/12800 [==============================] - 7s 535us/step - loss: 0.8185 - val_loss: 0.9956
# Epoch 64/100
# 12800/12800 [==============================] - 7s 538us/step - loss: 0.8100 - val_loss: 0.7368
# Epoch 65/100
# 12800/12800 [==============================] - 7s 533us/step - loss: 0.8065 - val_loss: 0.8246
# Epoch 66/100
# 12800/12800 [==============================] - 7s 539us/step - loss: 0.8153 - val_loss: 0.7393
# Epoch 67/100
# 12800/12800 [==============================] - 7s 537us/step - loss: 0.8109 - val_loss: 0.7343
# Epoch 68/100
# 12800/12800 [==============================] - 7s 536us/step - loss: 0.8239 - val_loss: 1.1438
# Epoch 69/100
# 12800/12800 [==============================] - 7s 535us/step - loss: 0.8136 - val_loss: 0.8370
# Epoch 70/100
# 12800/12800 [==============================] - 7s 536us/step - loss: 0.8021 - val_loss: 0.7622
# Epoch 71/100
# 12800/12800 [==============================] - 7s 535us/step - loss: 0.7902 - val_loss: 0.7309
# Epoch 72/100
# 12800/12800 [==============================] - 7s 537us/step - loss: 0.7928 - val_loss: 0.7383
# Epoch 73/100
# 12800/12800 [==============================] - 7s 535us/step - loss: 0.8000 - val_loss: 1.0298
# Epoch 74/100
# 12800/12800 [==============================] - 7s 532us/step - loss: 0.7970 - val_loss: 0.7133
# Epoch 75/100
# 12800/12800 [==============================] - 7s 534us/step - loss: 0.7980 - val_loss: 0.9340
# Epoch 76/100
# 12800/12800 [==============================] - 7s 535us/step - loss: 0.8170 - val_loss: 0.7439
# Epoch 77/100
# 12800/12800 [==============================] - 7s 540us/step - loss: 0.8180 - val_loss: 0.7862
# Epoch 78/100
# 12800/12800 [==============================] - 7s 538us/step - loss: 0.8045 - val_loss: 0.7694
# Epoch 79/100
# 12800/12800 [==============================] - 7s 535us/step - loss: 0.7989 - val_loss: 0.7514
# Epoch 80/100
# 12800/12800 [==============================] - 7s 536us/step - loss: 0.8015 - val_loss: 0.9016
# Epoch 81/100
# 12800/12800 [==============================] - 7s 536us/step - loss: 0.8308 - val_loss: 0.8283
# Epoch 82/100
# 12800/12800 [==============================] - 7s 538us/step - loss: 0.8115 - val_loss: 0.7678
# Epoch 83/100
# 12800/12800 [==============================] - 7s 535us/step - loss: 0.7715 - val_loss: 0.8835
# Epoch 84/100
# 12800/12800 [==============================] - 7s 535us/step - loss: 0.7930 - val_loss: 0.8070
# Epoch 85/100
# 12800/12800 [==============================] - 7s 533us/step - loss: 0.7914 - val_loss: 0.7230
# Epoch 86/100
# 12800/12800 [==============================] - 7s 537us/step - loss: 0.8047 - val_loss: 0.7751
# Epoch 87/100
# 12800/12800 [==============================] - 7s 533us/step - loss: 0.7859 - val_loss: 0.7425
# Epoch 88/100
# 12800/12800 [==============================] - 7s 533us/step - loss: 0.7950 - val_loss: 0.7670
# Epoch 89/100
# 12800/12800 [==============================] - 7s 538us/step - loss: 0.8161 - val_loss: 0.7700
# Epoch 90/100
# 12800/12800 [==============================] - 7s 534us/step - loss: 0.7876 - val_loss: 0.8111
# Epoch 91/100
# 12800/12800 [==============================] - 7s 537us/step - loss: 0.7779 - val_loss: 0.7255
# Epoch 92/100
# 12800/12800 [==============================] - 7s 538us/step - loss: 0.8050 - val_loss: 0.7266
# Epoch 93/100
# 12800/12800 [==============================] - 7s 536us/step - loss: 0.8106 - val_loss: 0.7207
# Epoch 94/100
# 12800/12800 [==============================] - 7s 534us/step - loss: 0.7908 - val_loss: 0.7274
# Epoch 95/100
# 12800/12800 [==============================] - 7s 535us/step - loss: 0.7928 - val_loss: 0.9182
# Epoch 96/100
# 12800/12800 [==============================] - 7s 536us/step - loss: 0.7859 - val_loss: 0.8506
# Epoch 97/100
# 12800/12800 [==============================] - 7s 534us/step - loss: 0.8432 - val_loss: 0.7437
# Epoch 98/100
# 12800/12800 [==============================] - 7s 536us/step - loss: 0.7911 - val_loss: 0.7473
# Epoch 99/100
# 12800/12800 [==============================] - 7s 536us/step - loss: 0.7961 - val_loss: 0.7368
# Epoch 100/100
# 12800/12800 [==============================] - 7s 537us/step - loss: 0.7894 - val_loss: 0.8143

# %%
cd ..
# Out:
# /content/drive/My Drive/concrete_crack

# %%
os.mkdir('model2')

# %%
cd model2/
# Out:
# /content/drive/My Drive/concrete_crack/model2

# %%
save_model(encoder,filepath='encoder.h5')
save_model(decoder,filepath='decoder.h5')
save_model(autoencoder,filepath='autoencoder.h5')

# %%
np.save('model1_history', history.history, allow_pickle=True)

# %%
np.save('training_loss', history.history['loss'], allow_pickle=True)
np.save('validation_loss', history.history['val_loss'], allow_pickle=True)

# %%
plt.plot(np.load('training_loss.npy', allow_pickle=True))
