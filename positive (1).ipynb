# %%
import os

# %%
import pandas as pd

# %%
import numpy as np

# %%
# !unrar l 'Concrete Crack Images for Classification.rar'

# %%
import shutil

# %%
for i in os.listdir(os.getcwd()):
  if i.endswith('.jpg'):
    os.remove(os.path.join(os.getcwd(), i))

# %%
# !pip install rarfile
# Out:
# ...
#      |████████████████████████████████| 122kB 8.4MB/s
# ...
#   Created wheel for rarfile: filename=rarfile-3.1-cp36-none-any.whl size=24908 sha256=ff94fdeb1749a4fc3bd12e28e78242185687bc88d9ffb7e3c8f457858227090d
#   Stored in directory: /root/.cache/pip/wheels/23/3c/c8/0215b6a5079492eff3be3f545ae0b0c4a66734c35c9e444eac
# Successfully built rarfile
# ...

# %%
from rarfile import RarFile

# %%
file_names = []
with RarFile('Concrete Crack Images for Classification.rar') as file:
    file_names.append((file.namelist()[0]))

# %%
file_names
# Out:
# ['Positive/00001.jpg']

# %%
os.mkdir('Positive')
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# <ipython-input-57-4355d52c3a0b> in <module>()
# ----> 1 os.mkdir('Positive')
#
# FileExistsError: [Errno 17] File exists: 'Positive'

# %%
cd Positive/
# Out:
# /content/drive/My Drive/concrete_crack/Positive

# %%
os.listdir(os.getcwd())
# Out:
# ['00001.jpg']

# %%
cd ..
# Out:
# /content/drive/My Drive/concrete_crack

# %%
os.listdir(os.getcwd())
# Out:
# ['Concrete Crack Images for Classification.rar', 'Untitled0.ipynb', 'Positive']

# %%
cd Positive/
# Out:
# /content/drive/My Drive/concrete_crack/Positive

# %%
cd ..
# Out:
# /content/drive/My Drive/concrete_crack

# %%
file = RarFile('Concrete Crack Images for Classification.rar')

# %%
for i in file.namelist():
  if 'Positive' in i:
    file.extract(i)

# %%
ls
# Out:
# 'Concrete Crack Images for Classification.rar'   Positive/   positive.ipynb

# %%
cd Positive/
# Out:
# /content/drive/My Drive/concrete_crack/Positive

# %%
len(os.listdir(os.getcwd()))
# Out:
# 20002

# %%
for i in os.listdir(os.getcwd()):
  if 'jpg' not in i:
    print(i)
# Out:
# Positive
# Negative

# %%
cd Positive/
# Out:
# /content/drive/My Drive/concrete_crack/Positive/Positive

# %%
len(os.listdir(os.getcwd()))
# Out:
# 20000

# %%
cd ..
# Out:
# /content/drive/My Drive/concrete_crack/Positive

# %%
os.listdir(os.getcwd())

# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.imshow(cv2.imread(os.listdir(os.getcwd())[0]))

# %%
cd ..
# Out:
# /content/drive/My Drive/concrete_crack/Positive

# %%
cd Negative/
# Out:
# /content/drive/My Drive/concrete_crack/Positive/Negative

# %%
plt.imshow(cv2.imread(os.listdir(os.getcwd())[0]))

# %%
cv2.imread(os.listdir(os.getcwd())[0]).shape
# Out:
# (227, 227, 3)

# %%
cd ..
# Out:
# /content/drive/My Drive/concrete_crack/Positive

# %%
plt.imshow(cv2.imread(os.listdir(os.getcwd())[0]))

# %%
cv2.imread(os.listdir(os.getcwd())[0]).shape
# Out:
# (227, 227, 3)

# %%
cd Negative/
# Out:
# /content/drive/My Drive/concrete_crack/Positive/Negative
