# %%
cd drive/My\ Drive/concrete_crack
# Out:
# /content/drive/My Drive/concrete_crack

# %%
import os

# %%
len(os.listdir(os.getcwd()))
# Out:
# 13466

# %%
os.mkdir('negative')

# %%
cd negative/
# Out:
# /content/drive/My Drive/concrete_crack/negative

# %%
negative_path = os.getcwd()

# %%
cd ..
# Out:
# /content/drive/My Drive/concrete_crack

# %%
import shutil

# %%
shutil.copy(os.path.join(os.getcwd(), 'Concrete Crack Images for Classification.rar'), os.path.join(negative_path, 'Concrete Crack Images for Classification.rar'))
# Out:
# '/content/drive/My Drive/concrete_crack/negative/Concrete Crack Images for Classification.rar'

# %%
cd negative/
# Out:
# /content/drive/My Drive/concrete_crack/negative

# %%
ls
# Out:
# 'Concrete Crack Images for Classification.rar'

# %%
pip install rarfile
# Out:
# ...
#      |████████████████████████████████| 122kB 4.6MB/s
# ...
#   Created wheel for rarfile: filename=rarfile-3.1-cp36-none-any.whl size=24908 sha256=2e415aeac8277458e5b8e30cfbb41849027bd30e0712d90c5976a1fd7f8c7ed7
#   Stored in directory: /root/.cache/pip/wheels/23/3c/c8/0215b6a5079492eff3be3f545ae0b0c4a66734c35c9e444eac
# Successfully built rarfile
# ...

# %%
from rarfile import RarFile

# %%
file = RarFile('Concrete Crack Images for Classification.rar')

# %%
for i in file.namelist():
  if 'Negative' in i:
    file.extract(i)

# %%
import os

# %%
len(os.listdir(os.getcwd()))
# Out:
# 2

# %%
ls
# Out:
# 'Concrete Crack Images for Classification.rar'   Negative/

# %%
cd Negative/
# Out:
# /content/drive/My Drive/concrete_crack/negative/Negative

# %%
len(os.listdir(os.getcwd()))
# Out:
# 20002

# %%
cd Positive/
# Out:
# /content/drive/My Drive/concrete_crack/negative/Negative/Positive

# %%
len(os.listdir(os.getcwd()))
# Out:
# 20000

# %%
cd ..
# Out:
# /content/drive/My Drive/concrete_crack/negative/Negative
