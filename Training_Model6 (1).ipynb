# %%
cd drive/My\ Drive/concrete_crack
# Out:
# /content/drive/My Drive/concrete_crack

# %%
import numpy as np
import keras.utils
from keras.layers import Input, Dense, Flatten
from keras.models import load_model, Model
from keras.layers import Conv2D, UpSampling2D, AveragePooling2D
from keras.layers import LeakyReLU, Reshape
from keras.datasets import mnist
from keras.models import save_model
from keras import backend as K
import tensorflow as tf
import matplotlib.pyplot as plt
from IPython import display
import time
# Out:
# Using TensorFlow backend.

# %%
import os

# %%
def generateTheta(L, endim):
  sample = np.random.uniform(size = (L, endim))
  theta = [w/np.sqrt((w**2).sum()) for w in sample]
  return np.asarray(theta)

def generateZ(batchsize, endim):
  z = np.random.uniform(size = (batchsize, endim))
  z = z - 0.5
  z = 2*z 
  return z

# %%
L = 50
batchsize = 32
endim = 2

# %%
img = Input(shape = (64,64,1))
x = Conv2D(16, (3,3), padding = 'same')(img)
x = LeakyReLU(alpha = 0.2)(x)
x = Conv2D(16, (3,3), padding = 'same')(x)
x = LeakyReLU(alpha = 0.2)(x)
x = AveragePooling2D((2,2), padding = 'same')(x) #(none, 14, 14, 16)

x = Conv2D(32, (3,3), padding = 'same')(x)
x = LeakyReLU(alpha = 0.2)(x)
x = Conv2D(32, (3,3), padding = 'same')(x)
x = LeakyReLU(alpha = 0.2)(x)
x = AveragePooling2D((2,2), padding = 'same')(x) #(none, 7, 7, 32)

x = Conv2D(64, (3,3), padding = 'same')(x)
x = LeakyReLU(alpha = 0.2)(x)
x = Conv2D(64, (3,3), padding = 'same')(x)
x = LeakyReLU(alpha = 0.2)(x)
x = AveragePooling2D((2,2), padding = 'same')(x) #(none, 4, 4, 64)

x = Flatten()(x) #(none, 4*4*64)
x = Dense(128, activation = 'relu')(x)
encoded = Dense(endim)(x)

encoder = Model(inputs = [img], outputs = [encoded])
encoder.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 64, 64, 1)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 64, 64, 16)        160
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 64, 64, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 64, 64, 16)        2320
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 64, 64, 16)        0
# _________________________________________________________________
# average_pooling2d_1 (Average (None, 32, 32, 16)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 32)        4640
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 32, 32, 32)        9248
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 32, 32, 32)        0
# _________________________________________________________________
# average_pooling2d_2 (Average (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 16, 16, 64)        18496
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 16, 16, 64)        36928
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 16, 16, 64)        0
# _________________________________________________________________
# average_pooling2d_3 (Average (None, 8, 8, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 4096)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               524416
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 258
# =================================================================
# Total params: 596,466
# Trainable params: 596,466
# Non-trainable params: 0
# _________________________________________________________________

# %%
embedd = Input(shape = (endim, ))
x = Dense(128)(embedd)
x = Dense(8*8*64, activation = 'relu')(x)
x = Reshape((8,8,64))(x)
x = UpSampling2D((2,2))(x) #(none, 8, 8, 64)

x = Conv2D(64, (3,3), padding='same')(x)
x = LeakyReLU(alpha = 0.2)(x)
x = Conv2D(64, (3,3), padding = 'same')(x)
x = LeakyReLU(alpha = 0.2)(x)
x = UpSampling2D((2,2))(x) #(none, 16, 16, 64)

x = Conv2D(64, (3,3), padding = 'same')(x)
x = LeakyReLU(alpha = 0.2)(x)
x = Conv2D(64, (3,3), padding = 'same')(x)
x = LeakyReLU(alpha = 0.2)(x)
x = UpSampling2D((2,2))(x) #(none, 28, 28, 64)

x = Conv2D(32, (3,3), padding = 'same')(x)
x = LeakyReLU(alpha = 0.2)(x)
x = Conv2D(32, (3,3), padding = 'same')(x)
x = LeakyReLU(alpha = 0.2)(x)
decoded = Conv2D(1, (3,3), padding = 'same', activation = 'sigmoid')(x)

decoder = Model(inputs = [embedd], outputs = [decoded])
decoder.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 2)                 0
# _________________________________________________________________
# dense_3 (Dense)              (None, 128)               384
# _________________________________________________________________
# dense_4 (Dense)              (None, 4096)              528384
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 8, 8, 64)          0
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 16, 16, 64)        36928
# _________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)    (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 16, 16, 64)        36928
# _________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)    (None, 16, 16, 64)        0
# _________________________________________________________________
# up_sampling2d_2 (UpSampling2 (None, 32, 32, 64)        0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 32, 32, 64)        36928
# _________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)    (None, 32, 32, 64)        0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 32, 32, 64)        36928
# _________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)   (None, 32, 32, 64)        0
# _________________________________________________________________
# up_sampling2d_3 (UpSampling2 (None, 64, 64, 64)        0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 64, 64, 32)        18464
# _________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)   (None, 64, 64, 32)        0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 64, 64, 32)        9248
# _________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)   (None, 64, 64, 32)        0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 64, 64, 1)         289
# =================================================================
# Total params: 704,481
# Trainable params: 704,481
# Non-trainable params: 0
# _________________________________________________________________

# %%
theta = K.variable(generateTheta(L, endim))
z = K.variable(generateZ(batchsize, endim))

# %%
encoded_image = encoder(img)
decoded_image = decoder(encoded_image)
autoencoder = Model(inputs = [img], outputs = [decoded_image])
autoencoder.summary()
# Out:
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 64, 64, 1)         0
# _________________________________________________________________
# model_1 (Model)              (None, 2)                 596466
# _________________________________________________________________
# model_2 (Model)              (None, 64, 64, 1)         704481
# =================================================================
# Total params: 1,300,947
# Trainable params: 1,300,947
# Non-trainable params: 0
# _________________________________________________________________

# %%
proj_encoded = K.dot(encoded_image, K.transpose(theta))
proj_z = K.dot(z, K.transpose(theta))

# %%
proj_encoded_transposed = tf.nn.top_k(tf.transpose(proj_encoded), k = batchsize).values
proj_z_transposed = tf.nn.top_k(tf.transpose(proj_z), k = batchsize).values
w2 = (proj_encoded_transposed - proj_z_transposed)**2
w2weight = K.variable(10.0)
w2loss = w2weight * K.mean(w2)

# %%
crossEntropy = K.binary_crossentropy(K.flatten(img), K.flatten(decoded_image))
crossEntropyLoss = (1.0) * K.mean(crossEntropy)

# %%
l1Loss = (1.0) * K.mean(K.abs(K.flatten(img) - K.flatten(decoded_image)))

# %%
total_loss = w2loss + crossEntropyLoss + l1Loss

# %%
autoencoder.add_loss(total_loss)

# %%
autoencoder.compile(optimizer = 'rmsprop', loss = '')
# Out:
# /usr/local/lib/python3.6/dist-packages/keras/engine/training_utils.py:819: UserWarning: Output model_2 missing from loss dictionary. We assume this was done on purpose. The fit and evaluate APIs will not be expecting any data to be passed to model_2.
#   'be expecting any data to be passed to {0}.'.format(name))

# %%
cd data_64/
# Out:
# /content/drive/My Drive/concrete_crack/data_64

# %%
X_train = np.load('X_train.npy', allow_pickle=True)

# %%
history = autoencoder.fit(X_train, None, validation_split=0.2, epochs = 100, batch_size = 32)
# Out:
# Train on 12800 samples, validate on 3200 samples
# Epoch 1/100
# 12800/12800 [==============================] - 34s 3ms/step - loss: 3.5451 - val_loss: 1.9638
# Epoch 2/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 1.9386 - val_loss: 0.8792
# Epoch 3/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 1.4270 - val_loss: 1.0095
# Epoch 4/100
# 12800/12800 [==============================] - 29s 2ms/step - loss: 1.1421 - val_loss: 0.8578
# Epoch 5/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 1.1273 - val_loss: 1.1611
# Epoch 6/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 1.0915 - val_loss: 1.0517
# Epoch 7/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 1.0431 - val_loss: 0.9260
# Epoch 8/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 1.0393 - val_loss: 0.8623
# Epoch 9/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.9738 - val_loss: 0.9456
# Epoch 10/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.9952 - val_loss: 1.0694
# Epoch 11/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.9775 - val_loss: 0.8689
# Epoch 12/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.9995 - val_loss: 0.9825
# Epoch 13/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 1.0135 - val_loss: 0.9246
# Epoch 14/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.9684 - val_loss: 0.8754
# Epoch 15/100
# 12800/12800 [==============================] - 29s 2ms/step - loss: 0.9369 - val_loss: 0.9241
# Epoch 16/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.9483 - val_loss: 1.0583
# Epoch 17/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.9767 - val_loss: 0.8943
# Epoch 18/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.9589 - val_loss: 0.8942
# Epoch 19/100
# 12800/12800 [==============================] - 29s 2ms/step - loss: 0.9364 - val_loss: 0.9016
# Epoch 20/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.9402 - val_loss: 0.8733
# Epoch 21/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.9233 - val_loss: 0.8403
# Epoch 22/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.9264 - val_loss: 0.8930
# Epoch 23/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.9728 - val_loss: 0.9656
# Epoch 24/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.9380 - val_loss: 0.9113
# Epoch 25/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.9287 - val_loss: 0.8729
# Epoch 26/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.9362 - val_loss: 0.8679
# Epoch 27/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.9142 - val_loss: 0.8814
# Epoch 28/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.9285 - val_loss: 0.9555
# Epoch 29/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.9403 - val_loss: 1.3665
# Epoch 30/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.9244 - val_loss: 0.8877
# Epoch 31/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.9599 - val_loss: 0.8898
# Epoch 32/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.9234 - val_loss: 1.1663
# Epoch 33/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.9150 - val_loss: 0.8844
# Epoch 34/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.9046 - val_loss: 0.8921
# Epoch 35/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.9027 - val_loss: 0.8592
# Epoch 36/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.9078 - val_loss: 1.0350
# Epoch 37/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.9197 - val_loss: 0.9578
# Epoch 38/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.8942 - val_loss: 0.8681
# Epoch 39/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.9114 - val_loss: 0.8922
# Epoch 40/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.9199 - val_loss: 0.8867
# Epoch 41/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.9141 - val_loss: 1.6777
# Epoch 42/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.8879 - val_loss: 0.8710
# Epoch 43/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.8864 - val_loss: 0.8705
# Epoch 44/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.9598 - val_loss: 0.8859
# Epoch 45/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.9102 - val_loss: 0.8458
# Epoch 46/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.9148 - val_loss: 0.8575
# Epoch 47/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.8996 - val_loss: 0.9536
# Epoch 48/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.8921 - val_loss: 0.9149
# Epoch 49/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.9130 - val_loss: 0.8421
# Epoch 50/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.9051 - val_loss: 0.9104
# Epoch 51/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.8906 - val_loss: 1.1384
# Epoch 52/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.8953 - val_loss: 0.9633
# Epoch 53/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.9219 - val_loss: 0.8676
# Epoch 54/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.9006 - val_loss: 0.8907
# Epoch 55/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.8920 - val_loss: 0.8810
# Epoch 56/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.8877 - val_loss: 0.8730
# Epoch 57/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.8915 - val_loss: 0.8715
# Epoch 58/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.8840 - val_loss: 0.9624
# Epoch 59/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.8921 - val_loss: 1.0114
# Epoch 60/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.8779 - val_loss: 0.9833
# Epoch 61/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.8979 - val_loss: 0.8492
# Epoch 62/100
# 12800/12800 [==============================] - 29s 2ms/step - loss: 0.8826 - val_loss: 0.8669
# Epoch 63/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.8862 - val_loss: 0.9516
# Epoch 64/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.8729 - val_loss: 0.8966
# Epoch 65/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.8950 - val_loss: 0.8569
# Epoch 66/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.8693 - val_loss: 0.8715
# Epoch 67/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.8740 - val_loss: 0.9073
# Epoch 68/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.8874 - val_loss: 0.8812
# Epoch 69/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.8670 - val_loss: 0.9098
# Epoch 70/100
# 12800/12800 [==============================] - 29s 2ms/step - loss: 0.9058 - val_loss: 0.8487
# Epoch 71/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.8831 - val_loss: 0.8277
# Epoch 72/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.8820 - val_loss: 0.8582
# Epoch 73/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.8841 - val_loss: 1.2016
# Epoch 74/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.8662 - val_loss: 0.9527
# Epoch 75/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.8568 - val_loss: 1.0418
# Epoch 76/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.8772 - val_loss: 0.8510
# Epoch 77/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.8767 - val_loss: 0.9030
# Epoch 78/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.9003 - val_loss: 0.9080
# Epoch 79/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.8729 - val_loss: 0.8678
# Epoch 80/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.8790 - val_loss: 0.8452
# Epoch 81/100
# 12800/12800 [==============================] - 29s 2ms/step - loss: 0.8759 - val_loss: 1.0806
# Epoch 82/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.8799 - val_loss: 0.8979
# Epoch 83/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.8812 - val_loss: 0.8700
# Epoch 84/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.8683 - val_loss: 1.3488
# Epoch 85/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.8792 - val_loss: 0.9964
# Epoch 86/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.8906 - val_loss: 0.8942
# Epoch 87/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.8835 - val_loss: 0.8908
# Epoch 88/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 1.0160 - val_loss: 0.8563
# Epoch 89/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.8795 - val_loss: 0.9061
# Epoch 90/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.8823 - val_loss: 0.8806
# Epoch 91/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.8740 - val_loss: 0.8718
# Epoch 92/100
# 12800/12800 [==============================] - 29s 2ms/step - loss: 0.8617 - val_loss: 0.8930
# Epoch 93/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.8871 - val_loss: 0.9761
# Epoch 94/100
# 12800/12800 [==============================] - 29s 2ms/step - loss: 0.8738 - val_loss: 0.8583
# Epoch 95/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.8780 - val_loss: 0.8488
# Epoch 96/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.8757 - val_loss: 0.8817
# Epoch 97/100
# 12800/12800 [==============================] - 29s 2ms/step - loss: 0.8747 - val_loss: 1.0348
# Epoch 98/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.8836 - val_loss: 0.8477
# Epoch 99/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.8749 - val_loss: 0.8526
# Epoch 100/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.8753 - val_loss: 0.8550

# %%
cd ..
# Out:
# /content/drive/My Drive/concrete_crack

# %%
os.mkdir('model6')

# %%
cd model6/
# Out:
# /content/drive/My Drive/concrete_crack/model6

# %%
save_model(encoder,filepath='encoder.h5')
save_model(decoder,filepath='decoder.h5')
save_model(autoencoder,filepath='autoencoder.h5')

# %%
np.save('model1_history', history.history, allow_pickle=True)

# %%
np.save('training_loss', history.history['loss'], allow_pickle=True)
np.save('validation_loss', history.history['val_loss'], allow_pickle=True)

# %%
plt.plot(np.load('training_loss.npy', allow_pickle=True))
