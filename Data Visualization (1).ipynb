# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
cd drive/My\ Drive/concrete_crack
# Out:
# /content/drive/My Drive/concrete_crack

# %%
ls
# Out:
# 'Concrete Crack Images for Classification.rar'   negative.ipynb
# 'Creating Negative Data.ipynb'                   Positive/
# 'Creating Positive Data.ipynb'                   positive.ipynb
#  negative/                                       Untitled

# %%
cd Positive/
# Out:
# /content/drive/My Drive/concrete_crack/Positive

# %%
positive_path = os.getcwd()

# %%
cd ..
# Out:
# /content/drive/My Drive/concrete_crack

# %%
cd negative/Negative
# Out:
# /content/drive/My Drive/concrete_crack/negative/Negative

# %%
negative_path = os.getcwd()

# %%
cd ..
# Out:
# /content/drive/My Drive/concrete_crack/negative

# %%
cd ..
# Out:
# /content/drive/My Drive/concrete_crack

# %%
positive_images = os.listdir(positive_path)
negative_images = os.listdir(negative_path)

# %%
positive_images[0]
# Out:
# '02459.jpg'

# %%
negative_images[1]
# Out:
# '09449.jpg'

# %%
plt.imshow(cv2.imread(os.path.join(positive_path, '20000.jpg')))

# %%
plt.imshow(cv2.imread(os.path.join(negative_path, '20000.jpg')))

# %%
number = input('number')
# Out:
# number00501

# %%
img1 = cv2.imread(os.path.join(negative_path, str(number) + '.jpg'))

# %%
img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)

# %%
#plt.figure(figsize = (3,3))
plt.imshow(img1, cmap = 'gray')

# %%
img1 = cv2.resize(img1, (64, 64))

# %%
#plt.figure(figsize = (3,3))
plt.imshow(img1, cmap = 'gray')

# %%
img1 = cv2.resize(img1, (227,227), interpolation = cv2.INTER_AREA)
plt.imshow(img1, cmap = 'gray')

# %%
img2 = cv2.imread(os.path.join(positive_path, str(number) + '.jpg'))

# %%
img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)

# %%
plt.figure(figsize = (3,3))
plt.imshow(img2, cmap = 'gray')

# %%
img2 = cv2.resize(img2, (64,64))

# %%
plt.imshow(img2, cmap = 'gray')

# %%
img2 = cv2.resize(img2, (227,227), interpolation = cv2.INTER_AREA)

# %%
plt.imshow(img2, cmap = 'gray')

# %%
img1 = cv2.resize(img1, (227,227), interpolation = cv2.INTER_AREA)

# %%
plt.imshow(img1, cmap = 'gray')

# %%
img1 = cv2.resize(img1, (28,28), interpolation = cv2.INTER_AREA)

# %%
plt.imshow(img1, cmap = 'gray')

# %%
img1 = cv2.resize(img1, (227,227), interpolation = cv2.INTER_AREA)
plt.imshow(img1, cmap = 'gray')
