# %%
cd drive/My\ Drive/concrete_crack
# Out:
# /content/drive/My Drive/concrete_crack

# %%
import numpy as np
import keras.utils
from keras.layers import Input, Dense, Flatten
from keras.models import load_model, Model
from keras.layers import Conv2D, UpSampling2D, AveragePooling2D
from keras.layers import LeakyReLU, Reshape
from keras.models import save_model
from keras import backend as K
import tensorflow as tf
import matplotlib.pyplot as plt
from IPython import display
from sklearn.datasets import make_circles
import time
# Out:
# Using TensorFlow backend.

# %%
import os

# %%
def generateTheta(L, endim):
  samples = np.random.uniform(size = (L, endim))
  theta = [w/np.sqrt((w**2).sum()) for w in samples]
  return np.asarray(theta)

def generateZ(batchsize):
  temp = make_circles(2*batchsize, noise = 0.1)
  zeroth_index = np.where(temp[1] == 0)[0]
  temp_zero_values = temp[0][zeroth_index]
  return np.array(temp_zero_values)

# %%
L = 50
batchsize = 32
endim = 2

# %%
img = Input(shape = (64,64,1))
x = Conv2D(16, (3,3), padding = 'same')(img)
x = LeakyReLU(alpha = 0.2)(x)
x = Conv2D(16, (3,3), padding = 'same')(x)
x = LeakyReLU(alpha = 0.2)(x)
x = AveragePooling2D((2,2), padding = 'same')(x) #(none, 14, 14, 16)

x = Conv2D(32, (3,3), padding = 'same')(x)
x = LeakyReLU(alpha = 0.2)(x)
x = Conv2D(32, (3,3), padding = 'same')(x)
x = LeakyReLU(alpha = 0.2)(x)
x = AveragePooling2D((2,2), padding = 'same')(x) #(none, 7, 7, 32)

x = Conv2D(64, (3,3), padding = 'same')(x)
x = LeakyReLU(alpha = 0.2)(x)
x = Conv2D(64, (3,3), padding = 'same')(x)
x = LeakyReLU(alpha = 0.2)(x)
x = AveragePooling2D((2,2), padding = 'same')(x) #(none, 4, 4, 64)

x = Flatten()(x) #(none, 4*4*64)
x = Dense(128, activation = 'relu')(x)
encoded = Dense(endim)(x)

encoder = Model(inputs = [img], outputs = [encoded])
encoder.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 64, 64, 1)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 64, 64, 16)        160
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 64, 64, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 64, 64, 16)        2320
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 64, 64, 16)        0
# _________________________________________________________________
# average_pooling2d_1 (Average (None, 32, 32, 16)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 32)        4640
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 32, 32, 32)        9248
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 32, 32, 32)        0
# _________________________________________________________________
# average_pooling2d_2 (Average (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 16, 16, 64)        18496
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 16, 16, 64)        36928
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 16, 16, 64)        0
# _________________________________________________________________
# average_pooling2d_3 (Average (None, 8, 8, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 4096)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               524416
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 258
# =================================================================
# Total params: 596,466
# Trainable params: 596,466
# Non-trainable params: 0
# _________________________________________________________________

# %%
embedd = Input(shape = (endim, ))
x = Dense(128)(embedd)
x = Dense(8*8*64, activation = 'relu')(x)
x = Reshape((8,8,64))(x)
x = UpSampling2D((2,2))(x) #(none, 8, 8, 64)

x = Conv2D(64, (3,3), padding='same')(x)
x = LeakyReLU(alpha = 0.2)(x)
x = Conv2D(64, (3,3), padding = 'same')(x)
x = LeakyReLU(alpha = 0.2)(x)
x = UpSampling2D((2,2))(x) #(none, 16, 16, 64)

x = Conv2D(64, (3,3), padding = 'same')(x)
x = LeakyReLU(alpha = 0.2)(x)
x = Conv2D(64, (3,3), padding = 'same')(x)
x = LeakyReLU(alpha = 0.2)(x)
x = UpSampling2D((2,2))(x) #(none, 28, 28, 64)

x = Conv2D(32, (3,3), padding = 'same')(x)
x = LeakyReLU(alpha = 0.2)(x)
x = Conv2D(32, (3,3), padding = 'same')(x)
x = LeakyReLU(alpha = 0.2)(x)
decoded = Conv2D(1, (3,3), padding = 'same', activation = 'sigmoid')(x)

decoder = Model(inputs = [embedd], outputs = [decoded])
decoder.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 2)                 0
# _________________________________________________________________
# dense_3 (Dense)              (None, 128)               384
# _________________________________________________________________
# dense_4 (Dense)              (None, 4096)              528384
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 8, 8, 64)          0
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 16, 16, 64)        36928
# _________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)    (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 16, 16, 64)        36928
# _________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)    (None, 16, 16, 64)        0
# _________________________________________________________________
# up_sampling2d_2 (UpSampling2 (None, 32, 32, 64)        0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 32, 32, 64)        36928
# _________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)    (None, 32, 32, 64)        0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 32, 32, 64)        36928
# _________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)   (None, 32, 32, 64)        0
# _________________________________________________________________
# up_sampling2d_3 (UpSampling2 (None, 64, 64, 64)        0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 64, 64, 32)        18464
# _________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)   (None, 64, 64, 32)        0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 64, 64, 32)        9248
# _________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)   (None, 64, 64, 32)        0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 64, 64, 1)         289
# =================================================================
# Total params: 704,481
# Trainable params: 704,481
# Non-trainable params: 0
# _________________________________________________________________

# %%
theta = K.variable(generateTheta(L, endim))
z = K.variable(generateZ(batchsize))

# %%
encoded_image = encoder(img)
decoded_image = decoder(encoded_image)
autoencoder = Model(inputs = [img], outputs = [decoded_image])
autoencoder.summary()
# Out:
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 64, 64, 1)         0
# _________________________________________________________________
# model_1 (Model)              (None, 2)                 596466
# _________________________________________________________________
# model_2 (Model)              (None, 64, 64, 1)         704481
# =================================================================
# Total params: 1,300,947
# Trainable params: 1,300,947
# Non-trainable params: 0
# _________________________________________________________________

# %%
proj_encoded = K.dot(encoded_image, K.transpose(theta))
proj_z = K.dot(z, K.transpose(theta))

# %%
proj_encoded_transpose = tf.nn.top_k(tf.transpose(proj_encoded), k = batchsize).values
proj_z_transpose = tf.nn.top_k(tf.transpose(proj_z), k = batchsize).values

# %%
w2 = (proj_encoded_transpose - proj_z_transpose)**2
w2weight = K.variable(10.0)
w2loss = w2weight * K.mean(w2)

# %%
crossEntropy = K.binary_crossentropy(K.flatten(img), K.flatten(decoded_image))
crossEntropyLoss = 1.0 * K.mean(crossEntropy)

# %%
absolute_difference = K.abs(K.flatten(img) - K.flatten(decoded_image))
L1Loss = 1.0 * K.mean(absolute_difference)

# %%
total_loss = w2loss + crossEntropyLoss + L1Loss

# %%
autoencoder.add_loss(total_loss)
autoencoder.compile(optimizer = 'rmsprop', loss = '')
# Out:
# /usr/local/lib/python3.6/dist-packages/keras/engine/training_utils.py:819: UserWarning: Output model_2 missing from loss dictionary. We assume this was done on purpose. The fit and evaluate APIs will not be expecting any data to be passed to model_2.
#   'be expecting any data to be passed to {0}.'.format(name))

# %%
cd data_64
# Out:
# /content/drive/My Drive/concrete_crack/data_64

# %%
X_train = np.load('X_train.npy', allow_pickle=True)

# %%
history = autoencoder.fit(X_train, None, validation_split=0.2, epochs = 100, batch_size = 32)
# Out:
# Train on 12800 samples, validate on 3200 samples
# Epoch 1/100
# 12800/12800 [==============================] - 14s 1ms/step - loss: 9.4758 - val_loss: 3.4118
# Epoch 2/100
# 12800/12800 [==============================] - 9s 691us/step - loss: 3.0729 - val_loss: 2.0276
# Epoch 3/100
# 12800/12800 [==============================] - 9s 688us/step - loss: 2.0539 - val_loss: 2.0103
# Epoch 4/100
# 12800/12800 [==============================] - 9s 681us/step - loss: 2.6266 - val_loss: 1.6701
# Epoch 5/100
# 12800/12800 [==============================] - 9s 679us/step - loss: 1.4851 - val_loss: 3.7232
# Epoch 6/100
# 12800/12800 [==============================] - 9s 682us/step - loss: 1.4444 - val_loss: 1.2219
# Epoch 7/100
# 12800/12800 [==============================] - 9s 679us/step - loss: 1.3561 - val_loss: 4.2645
# Epoch 8/100
# 12800/12800 [==============================] - 9s 680us/step - loss: 1.3186 - val_loss: 4.5459
# Epoch 9/100
# 12800/12800 [==============================] - 9s 681us/step - loss: 1.3458 - val_loss: 1.0450
# Epoch 10/100
# 12800/12800 [==============================] - 9s 681us/step - loss: 1.3151 - val_loss: 1.1336
# Epoch 11/100
# 12800/12800 [==============================] - 9s 682us/step - loss: 1.2679 - val_loss: 1.2555
# Epoch 12/100
# 12800/12800 [==============================] - 9s 679us/step - loss: 1.2718 - val_loss: 1.0370
# Epoch 13/100
# 12800/12800 [==============================] - 9s 684us/step - loss: 1.2200 - val_loss: 1.1866
# Epoch 14/100
# 12800/12800 [==============================] - 9s 677us/step - loss: 1.1912 - val_loss: 1.0648
# Epoch 15/100
# 12800/12800 [==============================] - 9s 680us/step - loss: 1.2063 - val_loss: 1.0429
# Epoch 16/100
# 12800/12800 [==============================] - 9s 682us/step - loss: 1.2196 - val_loss: 1.2609
# Epoch 17/100
# 12800/12800 [==============================] - 9s 683us/step - loss: 1.1794 - val_loss: 1.2037
# Epoch 18/100
# 12800/12800 [==============================] - 9s 682us/step - loss: 1.1790 - val_loss: 1.1697
# Epoch 19/100
# 12800/12800 [==============================] - 9s 680us/step - loss: 1.1959 - val_loss: 1.0770
# Epoch 20/100
# 12800/12800 [==============================] - 9s 682us/step - loss: 1.1734 - val_loss: 1.1113
# Epoch 21/100
# 12800/12800 [==============================] - 9s 679us/step - loss: 1.2222 - val_loss: 1.1132
# Epoch 22/100
# 12800/12800 [==============================] - 9s 688us/step - loss: 1.1515 - val_loss: 1.1739
# Epoch 23/100
# 12800/12800 [==============================] - 9s 680us/step - loss: 1.1583 - val_loss: 1.0452
# Epoch 24/100
# 12800/12800 [==============================] - 9s 686us/step - loss: 1.1389 - val_loss: 1.0700
# Epoch 25/100
# 12800/12800 [==============================] - 9s 682us/step - loss: 1.1915 - val_loss: 1.0446
# Epoch 26/100
# 12800/12800 [==============================] - 9s 688us/step - loss: 1.1167 - val_loss: 1.0733
# Epoch 27/100
# 12800/12800 [==============================] - 9s 675us/step - loss: 1.1729 - val_loss: 1.0689
# Epoch 28/100
# 12800/12800 [==============================] - 9s 674us/step - loss: 1.1572 - val_loss: 1.0596
# Epoch 29/100
# 12800/12800 [==============================] - 9s 675us/step - loss: 1.2002 - val_loss: 1.0456
# Epoch 30/100
# 12800/12800 [==============================] - 9s 675us/step - loss: 1.1103 - val_loss: 1.1175
# Epoch 31/100
# 12800/12800 [==============================] - 9s 671us/step - loss: 1.1784 - val_loss: 1.1501
# Epoch 32/100
# 12800/12800 [==============================] - 9s 675us/step - loss: 1.1542 - val_loss: 1.0991
# Epoch 33/100
# 12800/12800 [==============================] - 9s 675us/step - loss: 1.1426 - val_loss: 1.0609
# Epoch 34/100
# 12800/12800 [==============================] - 9s 674us/step - loss: 1.1493 - val_loss: 1.0748
# Epoch 35/100
# 12800/12800 [==============================] - 9s 680us/step - loss: 1.1705 - val_loss: 1.1866
# Epoch 36/100
# 12800/12800 [==============================] - 9s 674us/step - loss: 1.1877 - val_loss: 1.8640
# Epoch 37/100
# 12800/12800 [==============================] - 9s 674us/step - loss: 1.1473 - val_loss: 1.0459
# Epoch 38/100
# 12800/12800 [==============================] - 9s 686us/step - loss: 1.1179 - val_loss: 1.0365
# Epoch 39/100
# 12800/12800 [==============================] - 9s 676us/step - loss: 1.1355 - val_loss: 1.0820
# Epoch 40/100
# 12800/12800 [==============================] - 9s 674us/step - loss: 1.1480 - val_loss: 1.0273
# Epoch 41/100
# 12800/12800 [==============================] - 9s 675us/step - loss: 1.1435 - val_loss: 1.0831
# Epoch 42/100
# 12800/12800 [==============================] - 9s 674us/step - loss: 1.1557 - val_loss: 1.4772
# Epoch 43/100
# 12800/12800 [==============================] - 9s 672us/step - loss: 1.1677 - val_loss: 1.0402
# Epoch 44/100
# 12800/12800 [==============================] - 9s 672us/step - loss: 1.1764 - val_loss: 1.0459
# Epoch 45/100
# 12800/12800 [==============================] - 9s 672us/step - loss: 1.1530 - val_loss: 1.2569
# Epoch 46/100
# 12800/12800 [==============================] - 9s 670us/step - loss: 1.1384 - val_loss: 1.0300
# Epoch 47/100
# 12800/12800 [==============================] - 9s 670us/step - loss: 1.2372 - val_loss: 1.0185
# Epoch 48/100
# 12800/12800 [==============================] - 9s 673us/step - loss: 1.1155 - val_loss: 1.2571
# Epoch 49/100
# 12800/12800 [==============================] - 9s 671us/step - loss: 1.1420 - val_loss: 1.0727
# Epoch 50/100
# 12800/12800 [==============================] - 9s 673us/step - loss: 1.1778 - val_loss: 1.0152
# Epoch 51/100
# 12800/12800 [==============================] - 9s 675us/step - loss: 1.1456 - val_loss: 1.0874
# Epoch 52/100
# 12800/12800 [==============================] - 9s 669us/step - loss: 1.1487 - val_loss: 1.1841
# Epoch 53/100
# 12800/12800 [==============================] - 9s 668us/step - loss: 1.1532 - val_loss: 1.0153
# Epoch 54/100
# 12800/12800 [==============================] - 9s 666us/step - loss: 1.0925 - val_loss: 1.0138
# Epoch 55/100
# 12800/12800 [==============================] - 9s 668us/step - loss: 1.1707 - val_loss: 1.0429
# Epoch 56/100
# 12800/12800 [==============================] - 9s 666us/step - loss: 1.0864 - val_loss: 1.1279
# Epoch 57/100
# 12800/12800 [==============================] - 9s 668us/step - loss: 1.1543 - val_loss: 1.0584
# Epoch 58/100
# 12800/12800 [==============================] - 9s 667us/step - loss: 1.1182 - val_loss: 1.0233
# Epoch 59/100
# 12800/12800 [==============================] - 9s 669us/step - loss: 1.1246 - val_loss: 2.3068
# Epoch 60/100
# 12800/12800 [==============================] - 9s 673us/step - loss: 1.1186 - val_loss: 1.8560
# Epoch 61/100
# 12800/12800 [==============================] - 9s 673us/step - loss: 1.1252 - val_loss: 1.0826
# Epoch 62/100
# 12800/12800 [==============================] - 9s 672us/step - loss: 1.1262 - val_loss: 1.2297
# Epoch 63/100
# 12800/12800 [==============================] - 9s 673us/step - loss: 1.1184 - val_loss: 1.0507
# Epoch 64/100
# 12800/12800 [==============================] - 9s 673us/step - loss: 1.1724 - val_loss: 1.0869
# Epoch 65/100
# 12800/12800 [==============================] - 9s 672us/step - loss: 1.1467 - val_loss: 1.4842
# Epoch 66/100
# 12800/12800 [==============================] - 9s 672us/step - loss: 1.0766 - val_loss: 1.0906
# Epoch 67/100
# 12800/12800 [==============================] - 9s 672us/step - loss: 1.1316 - val_loss: 1.0060
# Epoch 68/100
# 12800/12800 [==============================] - 9s 675us/step - loss: 1.0912 - val_loss: 1.0893
# Epoch 69/100
# 12800/12800 [==============================] - 9s 673us/step - loss: 1.1081 - val_loss: 1.0272
# Epoch 70/100
# 12800/12800 [==============================] - 9s 673us/step - loss: 1.1355 - val_loss: 1.2320
# Epoch 71/100
# 12800/12800 [==============================] - 9s 679us/step - loss: 1.1599 - val_loss: 1.0702
# Epoch 72/100
# 12800/12800 [==============================] - 9s 672us/step - loss: 1.0935 - val_loss: 1.0651
# Epoch 73/100
# 12800/12800 [==============================] - 9s 671us/step - loss: 1.1060 - val_loss: 1.0150
# Epoch 74/100
# 12800/12800 [==============================] - 9s 684us/step - loss: 1.1284 - val_loss: 1.1581
# Epoch 75/100
# 12800/12800 [==============================] - 9s 675us/step - loss: 1.1269 - val_loss: 1.1188
# Epoch 76/100
# 12800/12800 [==============================] - 9s 671us/step - loss: 1.0925 - val_loss: 1.0414
# Epoch 77/100
# 12800/12800 [==============================] - 9s 672us/step - loss: 1.0897 - val_loss: 1.1040
# Epoch 78/100
# 12800/12800 [==============================] - 9s 675us/step - loss: 1.1198 - val_loss: 1.0442
# Epoch 79/100
# 12800/12800 [==============================] - 9s 673us/step - loss: 1.0799 - val_loss: 1.0260
# Epoch 80/100
# 12800/12800 [==============================] - 9s 672us/step - loss: 1.1101 - val_loss: 1.0644
# Epoch 81/100
# 12800/12800 [==============================] - 9s 672us/step - loss: 1.0849 - val_loss: 1.0869
# Epoch 82/100
# 12800/12800 [==============================] - 9s 673us/step - loss: 1.0615 - val_loss: 1.0688
# Epoch 83/100
# 12800/12800 [==============================] - 9s 674us/step - loss: 1.1083 - val_loss: 1.0958
# Epoch 84/100
# 12800/12800 [==============================] - 9s 674us/step - loss: 1.0886 - val_loss: 1.0683
# Epoch 85/100
# 12800/12800 [==============================] - 9s 673us/step - loss: 1.0665 - val_loss: 1.0115
# Epoch 86/100
# 12800/12800 [==============================] - 9s 673us/step - loss: 1.1052 - val_loss: 1.0772
# Epoch 87/100
# 12800/12800 [==============================] - 9s 671us/step - loss: 1.1305 - val_loss: 0.9937
# Epoch 88/100
# 12800/12800 [==============================] - 9s 672us/step - loss: 1.1244 - val_loss: 1.0466
# Epoch 89/100
# 12800/12800 [==============================] - 9s 670us/step - loss: 1.0753 - val_loss: 1.0494
# Epoch 90/100
# 12800/12800 [==============================] - 9s 674us/step - loss: 1.1077 - val_loss: 1.2552
# Epoch 91/100
# 12800/12800 [==============================] - 9s 675us/step - loss: 1.0964 - val_loss: 1.0570
# Epoch 92/100
# 12800/12800 [==============================] - 9s 675us/step - loss: 1.0945 - val_loss: 1.0183
# Epoch 93/100
# 12800/12800 [==============================] - 9s 670us/step - loss: 1.0704 - val_loss: 1.0713
# Epoch 94/100
# 12800/12800 [==============================] - 9s 671us/step - loss: 1.0824 - val_loss: 1.0508
# Epoch 95/100
# 12800/12800 [==============================] - 9s 673us/step - loss: 1.0972 - val_loss: 1.0429
# Epoch 96/100
# 12800/12800 [==============================] - 9s 671us/step - loss: 1.1793 - val_loss: 1.1764
# Epoch 97/100
# 12800/12800 [==============================] - 9s 672us/step - loss: 1.0916 - val_loss: 1.0196
# Epoch 98/100
# 12800/12800 [==============================] - 9s 671us/step - loss: 1.9006 - val_loss: 1.0556
# Epoch 99/100
# 12800/12800 [==============================] - 9s 672us/step - loss: 1.0694 - val_loss: 1.0316
# Epoch 100/100
# 12800/12800 [==============================] - 9s 671us/step - loss: 1.0827 - val_loss: 1.0326

# %%
cd ..
# Out:
# /content/drive/My Drive/concrete_crack

# %%
os.mkdir('model5')

# %%
cd model5/
# Out:
# /content/drive/My Drive/concrete_crack/model5

# %%
save_model(encoder,filepath='encoder.h5')
save_model(decoder,filepath='decoder.h5')
save_model(autoencoder,filepath='autoencoder.h5')

# %%
np.save('model1_history', history.history, allow_pickle=True)

# %%
np.save('training_loss', history.history['loss'], allow_pickle=True)
np.save('validation_loss', history.history['val_loss'], allow_pickle=True)

# %%
plt.plot(np.load('training_loss.npy', allow_pickle=True))
