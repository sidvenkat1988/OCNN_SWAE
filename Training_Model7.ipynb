# %%
cd drive/My\ Drive/concrete_crack
# Out:
# /content/drive/My Drive/concrete_crack

# %%
import numpy as np
import keras.utils
from keras.layers import Input, Dense, Flatten
from keras.models import load_model, Model
from keras.layers import Conv2D, UpSampling2D, AveragePooling2D
from keras.layers import LeakyReLU, Reshape
from keras.datasets import mnist
from keras.models import save_model
from keras import backend as K
import tensorflow as tf
import matplotlib.pyplot as plt
from IPython import display
import time
# Out:
# Using TensorFlow backend.

# %%
import os

# %%
def generateTheta(L, endim):
  sample = np.random.uniform(size = (L, endim))
  theta = [w/np.sqrt((w**2).sum()) for w in sample]
  return np.asarray(theta)

def generateZ(batchsize, endim):
  z = np.random.uniform(size = (batchsize, endim))
  z = z - 0.5
  z = 2*z 
  return z

# %%
L = 50
batchsize = 32
endim = 128

# %%
img = Input(shape = (64,64,1))
x = Conv2D(16, (3,3), padding = 'same')(img)
x = LeakyReLU(alpha = 0.2)(x)
x = Conv2D(16, (3,3), padding = 'same')(x)
x = LeakyReLU(alpha = 0.2)(x)
x = AveragePooling2D((2,2), padding = 'same')(x) #(none, 14, 14, 16)

x = Conv2D(32, (3,3), padding = 'same')(x)
x = LeakyReLU(alpha = 0.2)(x)
x = Conv2D(32, (3,3), padding = 'same')(x)
x = LeakyReLU(alpha = 0.2)(x)
x = AveragePooling2D((2,2), padding = 'same')(x) #(none, 7, 7, 32)

x = Conv2D(64, (3,3), padding = 'same')(x)
x = LeakyReLU(alpha = 0.2)(x)
x = Conv2D(64, (3,3), padding = 'same')(x)
x = LeakyReLU(alpha = 0.2)(x)
x = AveragePooling2D((2,2), padding = 'same')(x) #(none, 4, 4, 64)

x = Flatten()(x) #(none, 4*4*64)
x = Dense(128, activation = 'relu')(x)
encoded = Dense(endim)(x)

encoder = Model(inputs = [img], outputs = [encoded])
encoder.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 64, 64, 1)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 64, 64, 16)        160
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 64, 64, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 64, 64, 16)        2320
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 64, 64, 16)        0
# _________________________________________________________________
# average_pooling2d_1 (Average (None, 32, 32, 16)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 32)        4640
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 32, 32, 32)        9248
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 32, 32, 32)        0
# _________________________________________________________________
# average_pooling2d_2 (Average (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 16, 16, 64)        18496
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 16, 16, 64)        36928
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 16, 16, 64)        0
# _________________________________________________________________
# average_pooling2d_3 (Average (None, 8, 8, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 4096)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               524416
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               16512
# =================================================================
# Total params: 612,720
# Trainable params: 612,720
# Non-trainable params: 0
# _________________________________________________________________

# %%
embedd = Input(shape = (endim, ))
x = Dense(128)(embedd)
x = Dense(8*8*64, activation = 'relu')(x)
x = Reshape((8,8,64))(x)
x = UpSampling2D((2,2))(x) #(none, 8, 8, 64)

x = Conv2D(64, (3,3), padding='same')(x)
x = LeakyReLU(alpha = 0.2)(x)
x = Conv2D(64, (3,3), padding = 'same')(x)
x = LeakyReLU(alpha = 0.2)(x)
x = UpSampling2D((2,2))(x) #(none, 16, 16, 64)

x = Conv2D(64, (3,3), padding = 'same')(x)
x = LeakyReLU(alpha = 0.2)(x)
x = Conv2D(64, (3,3), padding = 'same')(x)
x = LeakyReLU(alpha = 0.2)(x)
x = UpSampling2D((2,2))(x) #(none, 28, 28, 64)

x = Conv2D(32, (3,3), padding = 'same')(x)
x = LeakyReLU(alpha = 0.2)(x)
x = Conv2D(32, (3,3), padding = 'same')(x)
x = LeakyReLU(alpha = 0.2)(x)
decoded = Conv2D(1, (3,3), padding = 'same', activation = 'sigmoid')(x)

decoder = Model(inputs = [embedd], outputs = [decoded])
decoder.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dense_4 (Dense)              (None, 4096)              528384
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 8, 8, 64)          0
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 16, 16, 64)        36928
# _________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)    (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 16, 16, 64)        36928
# _________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)    (None, 16, 16, 64)        0
# _________________________________________________________________
# up_sampling2d_2 (UpSampling2 (None, 32, 32, 64)        0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 32, 32, 64)        36928
# _________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)    (None, 32, 32, 64)        0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 32, 32, 64)        36928
# _________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)   (None, 32, 32, 64)        0
# _________________________________________________________________
# up_sampling2d_3 (UpSampling2 (None, 64, 64, 64)        0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 64, 64, 32)        18464
# _________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)   (None, 64, 64, 32)        0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 64, 64, 32)        9248
# _________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)   (None, 64, 64, 32)        0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 64, 64, 1)         289
# =================================================================
# Total params: 720,609
# Trainable params: 720,609
# Non-trainable params: 0
# _________________________________________________________________

# %%
theta = K.variable(generateTheta(L, endim))
z = K.variable(generateZ(batchsize, endim))

# %%
encoded_image = encoder(img)
decoded_image = decoder(encoded_image)
autoencoder = Model(inputs = [img], outputs = [decoded_image])
autoencoder.summary()
# Out:
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 64, 64, 1)         0
# _________________________________________________________________
# model_1 (Model)              (None, 128)               612720
# _________________________________________________________________
# model_2 (Model)              (None, 64, 64, 1)         720609
# =================================================================
# Total params: 1,333,329
# Trainable params: 1,333,329
# Non-trainable params: 0
# _________________________________________________________________

# %%
proj_encoded = K.dot(encoded_image, K.transpose(theta))
proj_z = K.dot(z, K.transpose(theta))

# %%
proj_encoded_transposed = tf.nn.top_k(tf.transpose(proj_encoded), k = batchsize).values
proj_z_transposed = tf.nn.top_k(tf.transpose(proj_z), k = batchsize).values
w2 = (proj_encoded_transposed - proj_z_transposed)**2
w2weight = K.variable(10.0)
w2loss = w2weight * K.mean(w2)

# %%
crossEntropy = K.binary_crossentropy(K.flatten(img), K.flatten(decoded_image))
crossEntropyLoss = (1.0) * K.mean(crossEntropy)

# %%
l1Loss = (1.0) * K.mean(K.abs(K.flatten(img) - K.flatten(decoded_image)))

# %%
total_loss = w2loss + crossEntropyLoss + l1Loss

# %%
autoencoder.add_loss(total_loss)

# %%
autoencoder.compile(optimizer = 'rmsprop', loss = '')
# Out:
# /usr/local/lib/python3.6/dist-packages/keras/engine/training_utils.py:819: UserWarning: Output model_2 missing from loss dictionary. We assume this was done on purpose. The fit and evaluate APIs will not be expecting any data to be passed to model_2.
#   'be expecting any data to be passed to {0}.'.format(name))

# %%
cd data_64/
# Out:
# /content/drive/My Drive/concrete_crack/data_64

# %%
X_train = np.load('X_train.npy', allow_pickle=True)

# %%
history = autoencoder.fit(X_train, None, validation_split=0.2, epochs = 100, batch_size = 32)
# Out:
# Train on 12800 samples, validate on 3200 samples
# Epoch 1/100
# 12800/12800 [==============================] - 34s 3ms/step - loss: 5.4938 - val_loss: 1.9232
# Epoch 2/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 2.4343 - val_loss: 1.0265
# Epoch 3/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 1.7811 - val_loss: 0.9891
# Epoch 4/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 1.4220 - val_loss: 0.9941
# Epoch 5/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 1.2765 - val_loss: 0.9549
# Epoch 6/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 1.2216 - val_loss: 0.9792
# Epoch 7/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 1.1837 - val_loss: 1.1701
# Epoch 8/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 1.3208 - val_loss: 3.1357
# Epoch 9/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 1.1351 - val_loss: 0.9406
# Epoch 10/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 1.0917 - val_loss: 0.9905
# Epoch 11/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 1.1169 - val_loss: 1.0165
# Epoch 12/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 1.1008 - val_loss: 1.0231
# Epoch 13/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 1.0537 - val_loss: 0.9463
# Epoch 14/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 1.0467 - val_loss: 0.9276
# Epoch 15/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 1.0618 - val_loss: 1.0018
# Epoch 16/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 1.0720 - val_loss: 0.9168
# Epoch 17/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 1.0782 - val_loss: 0.9813
# Epoch 18/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 1.0183 - val_loss: 0.9342
# Epoch 19/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 1.0217 - val_loss: 0.9104
# Epoch 20/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 1.0357 - val_loss: 1.1780
# Epoch 21/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 1.0268 - val_loss: 1.2238
# Epoch 22/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 1.0031 - val_loss: 0.9169
# Epoch 23/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 1.0173 - val_loss: 0.9502
# Epoch 24/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 1.0242 - val_loss: 0.9765
# Epoch 25/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 1.0238 - val_loss: 0.9967
# Epoch 26/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.9836 - val_loss: 0.9728
# Epoch 27/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.9802 - val_loss: 1.0309
# Epoch 28/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.9965 - val_loss: 0.9064
# Epoch 29/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 1.0115 - val_loss: 0.9504
# Epoch 30/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 1.0263 - val_loss: 0.9324
# Epoch 31/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 1.0122 - val_loss: 0.9049
# Epoch 32/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 1.0048 - val_loss: 0.9616
# Epoch 33/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 1.0252 - val_loss: 0.9192
# Epoch 34/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 1.0136 - val_loss: 0.9006
# Epoch 35/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 1.0370 - val_loss: 0.9238
# Epoch 36/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.9839 - val_loss: 1.0525
# Epoch 37/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 1.0048 - val_loss: 0.9723
# Epoch 38/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.9944 - val_loss: 0.9549
# Epoch 39/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.9824 - val_loss: 0.9610
# Epoch 40/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.9840 - val_loss: 1.1543
# Epoch 41/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 1.0205 - val_loss: 0.9940
# Epoch 42/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.9786 - val_loss: 1.1976
# Epoch 43/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.9579 - val_loss: 0.9066
# Epoch 44/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.9561 - val_loss: 0.9956
# Epoch 45/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.9973 - val_loss: 0.9579
# Epoch 46/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 1.0146 - val_loss: 0.9123
# Epoch 47/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 1.0145 - val_loss: 0.9264
# Epoch 48/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 1.0615 - val_loss: 1.0272
# Epoch 49/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 1.0007 - val_loss: 0.9987
# Epoch 50/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.9662 - val_loss: 0.9206
# Epoch 51/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.9562 - val_loss: 0.9867
# Epoch 52/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.9971 - val_loss: 0.9617
# Epoch 53/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.9979 - val_loss: 0.9673
# Epoch 54/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.9839 - val_loss: 0.9534
# Epoch 55/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.9751 - val_loss: 0.9461
# Epoch 56/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.9707 - val_loss: 0.9771
# Epoch 57/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 1.1605 - val_loss: 0.9174
# Epoch 58/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.9884 - val_loss: 1.2623
# Epoch 59/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.9948 - val_loss: 0.8977
# Epoch 60/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.9798 - val_loss: 1.3794
# Epoch 61/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.9780 - val_loss: 1.0679
# Epoch 62/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.9678 - val_loss: 0.9843
# Epoch 63/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.9409 - val_loss: 0.9528
# Epoch 64/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 1.0444 - val_loss: 0.9146
# Epoch 65/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.9675 - val_loss: 1.0808
# Epoch 66/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.9787 - val_loss: 0.9018
# Epoch 67/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.9613 - val_loss: 0.9526
# Epoch 68/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.9536 - val_loss: 2.3090
# Epoch 69/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 1.0312 - val_loss: 1.2327
# Epoch 70/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.9626 - val_loss: 0.9854
# Epoch 71/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.9872 - val_loss: 0.9568
# Epoch 72/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.9665 - val_loss: 0.8780
# Epoch 73/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.9683 - val_loss: 0.9526
# Epoch 74/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.9564 - val_loss: 0.9863
# Epoch 75/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.9764 - val_loss: 0.8920
# Epoch 76/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 1.0494 - val_loss: 0.9467
# Epoch 77/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.9899 - val_loss: 1.0014
# Epoch 78/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.9937 - val_loss: 1.2424
# Epoch 79/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 1.0013 - val_loss: 0.9415
# Epoch 80/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.9962 - val_loss: 0.9035
# Epoch 81/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.9567 - val_loss: 0.9107
# Epoch 82/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.9699 - val_loss: 0.8962
# Epoch 83/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.9716 - val_loss: 0.9956
# Epoch 84/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.9502 - val_loss: 0.9341
# Epoch 85/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.9662 - val_loss: 0.9418
# Epoch 86/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.9687 - val_loss: 0.9378
# Epoch 87/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.9697 - val_loss: 0.9683
# Epoch 88/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.9768 - val_loss: 0.9384
# Epoch 89/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.9626 - val_loss: 0.9375
# Epoch 90/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.9523 - val_loss: 0.9741
# Epoch 91/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.9653 - val_loss: 0.9278
# Epoch 92/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.9699 - val_loss: 0.9358
# Epoch 93/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.9525 - val_loss: 0.8898
# Epoch 94/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.9563 - val_loss: 0.9045
# Epoch 95/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.9544 - val_loss: 0.9495
# Epoch 96/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 1.0001 - val_loss: 0.9766
# Epoch 97/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.9574 - val_loss: 0.8975
# Epoch 98/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.9386 - val_loss: 0.9409
# Epoch 99/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.9739 - val_loss: 0.9327
# Epoch 100/100
# 12800/12800 [==============================] - 28s 2ms/step - loss: 0.9560 - val_loss: 0.9342

# %%
cd ..
# Out:
# /content/drive/My Drive/concrete_crack

# %%
os.mkdir('model7')

# %%
cd model7/
# Out:
# /content/drive/My Drive/concrete_crack/model7

# %%
save_model(encoder,filepath='encoder.h5')
save_model(decoder,filepath='decoder.h5')
save_model(autoencoder,filepath='autoencoder.h5')

# %%
np.save('model1_history', history.history, allow_pickle=True)

# %%
np.save('training_loss', history.history['loss'], allow_pickle=True)
np.save('validation_loss', history.history['val_loss'], allow_pickle=True)

# %%
plt.plot(np.load('training_loss.npy', allow_pickle=True))
