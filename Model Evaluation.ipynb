# %%
cd drive/My\ Drive/concrete_crack
# Out:
# /content/drive/My Drive/concrete_crack

# %%
from keras.models import load_model
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import os

# %%
model_paths = [i for i in os.listdir(os.getcwd()) if 'model' in i and 'ocnn' not in i]

# %%
model_paths
# Out:
# ['model1',
#  'model2',
#  'model3',
#  'model4',
#  'model5',
#  'model6',
#  'model7',
#  'model8']

# %%
final_model_paths = [os.path.join(os.getcwd(), i) for i in model_paths]

# %%
final_model_paths
# Out:
# ['/content/drive/My Drive/concrete_crack/model1',
#  '/content/drive/My Drive/concrete_crack/model2',
#  '/content/drive/My Drive/concrete_crack/model3',
#  '/content/drive/My Drive/concrete_crack/model4',
#  '/content/drive/My Drive/concrete_crack/model5',
#  '/content/drive/My Drive/concrete_crack/model6',
#  '/content/drive/My Drive/concrete_crack/model7',
#  '/content/drive/My Drive/concrete_crack/model8']

# %%
models = []
for i in final_model_paths:
  for j in os.listdir(i):
    if 'h5' in j:
      models.append(os.path.join(i,j))

# %%
cd encoded_decoded_data_28/
# Out:
# /content/drive/My Drive/concrete_crack/encoded_decoded_data_28

# %%
ls
# Out:
# balanced/      dec2_i_28.npy  dec4_i_28.npy  enc2_i_28.npy  enc4_i_28.npy
# dec1_b_28.npy  dec3_b_28.npy  enc1_b_28.npy  enc3_b_28.npy  imbalanced/
# dec1_i_28.npy  dec3_i_28.npy  enc1_i_28.npy  enc3_i_28.npy
# dec2_b_28.npy  dec4_b_28.npy  enc2_b_28.npy  enc4_b_28.npy

# %%
def load_data(data):
  loaded_data = np.load(data, allow_pickle=True)
  return loaded_data

# %%
enc1_b_28 = load_data('enc1_b_28.npy')

# %%
dec1_b_28 = load_data('dec1_b_28.npy')

# %%
enc2_b_28 = load_data('enc2_b_28.npy')
dec2_b_28 = load_data('dec2_b_28.npy')

enc3_b_28 = load_data('enc3_b_28.npy')
dec3_b_28 = load_data('dec3_b_28.npy')

enc4_b_28 = load_data('enc4_b_28.npy')
dec4_b_28 = load_data('dec4_b_28.npy')

# %%
enc1_i_28 = load_data('enc1_i_28.npy')
dec1_i_28 = load_data('dec1_i_28.npy')

enc2_i_28 = load_data('enc2_i_28.npy')
dec2_i_28 = load_data('dec2_i_28.npy')

enc3_i_28 = load_data('enc3_i_28.npy')
dec3_i_28 = load_data('dec3_i_28.npy')

enc4_i_28 = load_data('enc4_i_28.npy')
dec4_i_28 = load_data('dec4_i_28.npy')

# %%
cd ..
# Out:
# /content/drive/My Drive/concrete_crack

# %%
cd encoded_decoded_data_64/
# Out:
# /content/drive/My Drive/concrete_crack/encoded_decoded_data_64

# %%
enc1_b_64 = load_data('enc1_b_64.npy')
dec1_b_64 = load_data('dec1_b_64.npy')

enc2_b_64 = load_data('enc2_b_64.npy')
dec2_b_64 = load_data('dec2_b_64.npy')

enc3_b_64 = load_data('enc3_b_64.npy')
dec3_b_64 = load_data('dec3_b_64.npy')

enc4_b_64 = load_data('enc4_b_64.npy')
dec4_b_64 = load_data('dec4_b_64.npy')

# %%
enc1_i_64 = load_data('enc1_i_64.npy')
dec1_i_64 = load_data('dec1_i_64.npy')

enc2_i_64 = load_data('enc2_i_64.npy')
dec2_i_64 = load_data('dec2_i_64.npy')

enc3_i_64 = load_data('enc3_i_64.npy')
dec3_i_64 = load_data('dec3_i_64.npy')

enc4_i_64 = load_data('enc4_i_64.npy')
dec4_i_64 = load_data('dec4_i_64.npy')

# %%
cd ..
# Out:
# /content/drive/My Drive/concrete_crack

# %%
cd data_28/
# Out:
# /content/drive/My Drive/concrete_crack/data_28

# %%
ls
# Out:
# rescaled_negative_data.npy  X_test_negative.npy
# rescaled_positive_data.npy  X_test_positive_balanced.npy
# X_test_balanced.npy         X_test_positive_imbalanced.npy
# X_test_imbalanced.npy       X_train.npy

# %%
X_test_balanced_28 = load_data('X_test_balanced.npy')
X_test_imbalanced_28 = load_data('X_test_imbalanced.npy')

# %%
cd ..
# Out:
# /content/drive/My Drive/concrete_crack

# %%
cd data_64/
# Out:
# /content/drive/My Drive/concrete_crack/data_64

# %%
X_test_balanced_64 = load_data('X_test_balanced.npy')
X_test_imbalanced_64 = load_data('X_test_imbalanced.npy')

# %%
plt.figure(figsize=(20, 12))
fig, ax = plt.subplots(4, 5)
ax[0,0].imshow(X_test_balanced_28[0].reshape(28,28), cmap = 'gray')
ax[0,1].imshow(dec1_b_28[0].reshape(28,28), cmap = 'gray')
ax[0,2].imshow(dec2_b_28[0].reshape(28,28), cmap = 'gray')
ax[0,3].imshow(dec3_b_28[0].reshape(28,28), cmap = 'gray')
ax[0,4].imshow(dec4_b_28[0].reshape(28,28), cmap = 'gray')
ax[1,0].imshow(X_test_balanced_28[-1].reshape(28,28), cmap = 'gray')
ax[1,1].imshow(dec1_b_28[-1].reshape(28,28), cmap = 'gray')
ax[1,2].imshow(dec2_b_28[-1].reshape(28,28), cmap = 'gray')
ax[1,3].imshow(dec3_b_28[-1].reshape(28,28), cmap = 'gray')
ax[1,4].imshow(dec4_b_28[-1].reshape(28,28), cmap = 'gray')
ax[2,0].imshow(X_test_balanced_64[1].reshape(64,64), cmap = 'gray')
ax[2,1].imshow(dec1_b_64[1].reshape(64,64), cmap = 'gray')
ax[2,2].imshow(dec2_b_64[1].reshape(64,64), cmap = 'gray')
ax[2,3].imshow(dec3_b_64[1].reshape(64,64), cmap = 'gray')
ax[2,4].imshow(dec4_b_64[1].reshape(64,64), cmap = 'gray')
ax[3,0].imshow(X_test_balanced_64[-1].reshape(64,64), cmap = 'gray')
ax[3,1].imshow(dec1_b_64[-1].reshape(64,64), cmap = 'gray')
ax[3,2].imshow(dec2_b_64[-1].reshape(64,64), cmap = 'gray')
ax[3,3].imshow(dec3_b_64[-1].reshape(64,64), cmap = 'gray')
ax[3,4].imshow(dec4_b_64[-1].reshape(64,64), cmap = 'gray')
ax[0,0].axis('off')
ax[0,1].axis('off')
ax[0,2].axis('off')
ax[0,3].axis('off')
ax[0,4].axis('off')
ax[1,0].axis('off')
ax[1,1].axis('off')
ax[1,2].axis('off')
ax[1,3].axis('off')
ax[1,4].axis('off')
ax[2,0].axis('off')
ax[2,1].axis('off')
ax[2,2].axis('off')
ax[2,3].axis('off')
ax[2,4].axis('off')
ax[3,0].axis('off')
ax[3,1].axis('off')
ax[3,2].axis('off')
ax[3,3].axis('off')
ax[3,4].axis('off')
plt.savefig('Originalandreconstructed.png')

# %%
cd ..
# Out:
# /content/drive/My Drive/concrete_crack

# %%
cd model1/
# Out:
# /content/drive/My Drive/concrete_crack/model1

# %%
ls
# Out:
# autoencoder.h5  encoder.h5          training_loss.npy
# decoder.h5      model1_history.npy  validation_loss.npy

# %%
plt.figure(figsize=(10, 6))
plt.plot(np.load('training_loss.npy', allow_pickle=True), label = 'Training Loss')
plt.plot(np.load('validation_loss.npy', allow_pickle=True), label = 'Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss of Model I')
plt.legend()
plt.show()

# %%
cd ..
# Out:
# /content/drive/My Drive/concrete_crack

# %%
cd model2
# Out:
# /content/drive/My Drive/concrete_crack/model2

# %%
plt.figure(figsize=(10, 6))
plt.plot(np.load('training_loss.npy', allow_pickle=True), label = 'Training Loss')
plt.plot(np.load('validation_loss.npy', allow_pickle=True), label = 'Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss of Model II')
plt.legend()
plt.show()

# %%
cd ..
# Out:
# /content/drive/My Drive/concrete_crack

# %%
cd model3
# Out:
# /content/drive/My Drive/concrete_crack/model3

# %%
plt.figure(figsize=(10, 6))
plt.plot(np.load('training_loss.npy', allow_pickle=True), label = 'Training Loss')
plt.plot(np.load('validation_loss.npy', allow_pickle=True), label = 'Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss of Model III')
plt.legend()
plt.show()

# %%
cd ..
# Out:
# /content/drive/My Drive/concrete_crack

# %%
cd model4
# Out:
# /content/drive/My Drive/concrete_crack/model4

# %%
plt.figure(figsize=(10, 6))
plt.plot(np.load('training_loss.npy', allow_pickle=True), label = 'Training Loss')
plt.plot(np.load('validation_loss.npy', allow_pickle=True), label = 'Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss of Model IV')
plt.legend()
plt.show()

# %%
cd ..
# Out:
# /content/drive/My Drive/concrete_crack

# %%
cd model5
# Out:
# /content/drive/My Drive/concrete_crack/model5

# %%
plt.figure(figsize=(10, 6))
plt.plot(np.load('training_loss.npy', allow_pickle=True), label = 'Training Loss')
plt.plot(np.load('validation_loss.npy', allow_pickle=True), label = 'Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss of Model V')
plt.legend()
plt.show()

# %%
cd ..
# Out:
# /content/drive/My Drive/concrete_crack

# %%
cd model6
# Out:
# /content/drive/My Drive/concrete_crack/model6

# %%
plt.figure(figsize=(10, 6))
plt.plot(np.load('training_loss.npy', allow_pickle=True), label = 'Training Loss')
plt.plot(np.load('validation_loss.npy', allow_pickle=True), label = 'Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss of Model VI')
plt.legend()
plt.show()

# %%
cd ..
# Out:
# /content/drive/My Drive/concrete_crack

# %%
cd model7/
# Out:
# /content/drive/My Drive/concrete_crack/model7

# %%
plt.figure(figsize=(10, 6))
plt.plot(np.load('training_loss.npy', allow_pickle=True), label = 'Training Loss')
plt.plot(np.load('validation_loss.npy', allow_pickle=True), label = 'Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss of Model VII')
plt.legend()
plt.show()

# %%
cd ..
# Out:
# /content/drive/My Drive/concrete_crack

# %%
cd model8/
# Out:
# /content/drive/My Drive/concrete_crack/model8

# %%
plt.figure(figsize=(10, 6))
plt.plot(np.load('training_loss.npy', allow_pickle=True), label = 'Training Loss')
plt.plot(np.load('validation_loss.npy', allow_pickle=True), label = 'Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss of Model VIII')
plt.legend()
plt.show()
