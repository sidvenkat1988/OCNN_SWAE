# %%
cd drive/My\ Drive/concrete_crack
# Out:
# /content/drive/My Drive/concrete_crack

# %%
import numpy as np
import keras.utils
from keras.layers import Input, Dense, Flatten
from keras.models import load_model, Model
from keras.layers import Conv2D, UpSampling2D, AveragePooling2D
from keras.layers import LeakyReLU, Reshape
from keras.datasets import mnist
from keras.models import save_model
from keras import backend as K
import tensorflow as tf
import matplotlib.pyplot as plt
from IPython import display
import time
# Out:
# Using TensorFlow backend.

# %%
import os

# %%
def generateTheta(L, endim):
  sample = np.random.uniform(size = (L, endim))
  theta = [w/np.sqrt((w**2).sum()) for w in sample]
  return np.asarray(theta)

def generateZ(batchsize, endim):
  z = np.random.uniform(size = (batchsize, endim))
  z = z - 0.5
  z = 2*z 
  return z

# %%
L = 50
batchsize = 64
endim = 128

# %%
img = Input(shape = (28,28,1))
x = Conv2D(16, (3,3), padding = 'same')(img)
x = LeakyReLU(alpha = 0.2)(x)
x = Conv2D(16, (3,3), padding = 'same')(x)
x = LeakyReLU(alpha = 0.2)(x)
x = AveragePooling2D((2,2), padding = 'same')(x) #(none, 14, 14, 16)

x = Conv2D(32, (3,3), padding = 'same')(x)
x = LeakyReLU(alpha = 0.2)(x)
x = Conv2D(32, (3,3), padding = 'same')(x)
x = LeakyReLU(alpha = 0.2)(x)
x = AveragePooling2D((2,2), padding = 'same')(x) #(none, 7, 7, 32)

x = Conv2D(64, (3,3), padding = 'same')(x)
x = LeakyReLU(alpha = 0.2)(x)
x = Conv2D(64, (3,3), padding = 'same')(x)
x = LeakyReLU(alpha = 0.2)(x)
x = AveragePooling2D((2,2), padding = 'same')(x) #(none, 4, 4, 64)

x = Flatten()(x) #(none, 4*4*64)
x = Dense(128, activation = 'relu')(x)
encoded = Dense(endim)(x)

encoder = Model(inputs = [img], outputs = [encoded])
encoder.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 28, 28, 1)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 28, 28, 16)        160
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 28, 28, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 28, 28, 16)        2320
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 28, 28, 16)        0
# _________________________________________________________________
# average_pooling2d_1 (Average (None, 14, 14, 16)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 14, 14, 32)        4640
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 14, 14, 32)        9248
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 14, 14, 32)        0
# _________________________________________________________________
# average_pooling2d_2 (Average (None, 7, 7, 32)          0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 7, 7, 64)          18496
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 7, 7, 64)          0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 7, 7, 64)          36928
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 7, 7, 64)          0
# _________________________________________________________________
# average_pooling2d_3 (Average (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               131200
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               16512
# =================================================================
# Total params: 219,504
# Trainable params: 219,504
# Non-trainable params: 0
# _________________________________________________________________

# %%
embedd = Input(shape = (endim, ))
x = Dense(128)(embedd)
x = Dense(4*4*64, activation = 'relu')(x)
x = Reshape((4,4,64))(x)
x = UpSampling2D((2,2))(x) #(none, 8, 8, 64)

x = Conv2D(64, (3,3), padding='same')(x)
x = LeakyReLU(alpha = 0.2)(x)
x = Conv2D(64, (3,3), padding = 'same')(x)
x = LeakyReLU(alpha = 0.2)(x)
x = UpSampling2D((2,2))(x) #(none, 16, 16, 64)

x = Conv2D(64, (3,3), padding = 'valid')(x)
x = LeakyReLU(alpha = 0.2)(x)
x = Conv2D(64, (3,3), padding = 'same')(x)
x = LeakyReLU(alpha = 0.2)(x)
x = UpSampling2D((2,2))(x) #(none, 28, 28, 64)

x = Conv2D(32, (3,3), padding = 'same')(x)
x = LeakyReLU(alpha = 0.2)(x)
x = Conv2D(32, (3,3), padding = 'same')(x)
x = LeakyReLU(alpha = 0.2)(x)
decoded = Conv2D(1, (3,3), padding = 'same', activation = 'sigmoid')(x)

decoder = Model(inputs = [embedd], outputs = [decoded])
decoder.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dense_4 (Dense)              (None, 1024)              132096
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 4, 4, 64)          0
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 8, 8, 64)          36928
# _________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)    (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 8, 8, 64)          36928
# _________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)    (None, 8, 8, 64)          0
# _________________________________________________________________
# up_sampling2d_2 (UpSampling2 (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 14, 14, 64)        36928
# _________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)    (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 14, 14, 64)        36928
# _________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)   (None, 14, 14, 64)        0
# _________________________________________________________________
# up_sampling2d_3 (UpSampling2 (None, 28, 28, 64)        0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 28, 28, 32)        18464
# _________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)   (None, 28, 28, 32)        0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 28, 28, 32)        9248
# _________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)   (None, 28, 28, 32)        0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 28, 28, 1)         289
# =================================================================
# Total params: 324,321
# Trainable params: 324,321
# Non-trainable params: 0
# _________________________________________________________________

# %%
theta = K.variable(generateTheta(L, endim))
z = K.variable(generateZ(batchsize, endim))

# %%
encoded_image = encoder(img)
decoded_image = decoder(encoded_image)
autoencoder = Model(inputs = [img], outputs = [decoded_image])
autoencoder.summary()
# Out:
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 28, 28, 1)         0
# _________________________________________________________________
# model_1 (Model)              (None, 128)               219504
# _________________________________________________________________
# model_2 (Model)              (None, 28, 28, 1)         324321
# =================================================================
# Total params: 543,825
# Trainable params: 543,825
# Non-trainable params: 0
# _________________________________________________________________

# %%
proj_encoded = K.dot(encoded_image, K.transpose(theta))
proj_z = K.dot(z, K.transpose(theta))

# %%
proj_encoded_transposed = tf.nn.top_k(tf.transpose(proj_encoded), k = batchsize).values
proj_z_transposed = tf.nn.top_k(tf.transpose(proj_z), k = batchsize).values
w2 = (proj_encoded_transposed - proj_z_transposed)**2
w2weight = K.variable(10.0)
w2loss = w2weight * K.mean(w2)

# %%
crossEntropy = K.binary_crossentropy(K.flatten(img), K.flatten(decoded_image))
crossEntropyLoss = (1.0) * K.mean(crossEntropy)

# %%
l1Loss = (1.0) * K.mean(K.abs(K.flatten(img) - K.flatten(decoded_image)))

# %%
total_loss = w2loss + crossEntropyLoss + l1Loss

# %%
autoencoder.add_loss(total_loss)

# %%
autoencoder.compile(optimizer = 'rmsprop', loss = '')
# Out:
# /usr/local/lib/python3.6/dist-packages/keras/engine/training_utils.py:819: UserWarning: Output model_2 missing from loss dictionary. We assume this was done on purpose. The fit and evaluate APIs will not be expecting any data to be passed to model_2.
#   'be expecting any data to be passed to {0}.'.format(name))

# %%
cd data_28
# Out:
# /content/drive/My Drive/concrete_crack/data_28

# %%
X_train = np.load('X_train.npy', allow_pickle=True)

# %%
history = autoencoder.fit(X_train, None, validation_split=0.2, epochs = 100, batch_size = 64)
# Out:
# Train on 12800 samples, validate on 3200 samples
# Epoch 1/100
# 12800/12800 [==============================] - 8s 649us/step - loss: 3.4713 - val_loss: 2.8494
# Epoch 2/100
# 12800/12800 [==============================] - 3s 230us/step - loss: 2.1940 - val_loss: 1.3964
# Epoch 3/100
# 12800/12800 [==============================] - 3s 233us/step - loss: 1.7542 - val_loss: 1.6951
# Epoch 4/100
# 12800/12800 [==============================] - 3s 229us/step - loss: 1.4964 - val_loss: 1.2487
# Epoch 5/100
# 12800/12800 [==============================] - 3s 229us/step - loss: 1.3666 - val_loss: 1.3199
# Epoch 6/100
# 12800/12800 [==============================] - 3s 232us/step - loss: 1.2972 - val_loss: 1.0065
# Epoch 7/100
# 12800/12800 [==============================] - 3s 231us/step - loss: 1.2460 - val_loss: 0.9528
# Epoch 8/100
# 12800/12800 [==============================] - 3s 232us/step - loss: 1.1783 - val_loss: 1.3492
# Epoch 9/100
# 12800/12800 [==============================] - 3s 229us/step - loss: 1.1604 - val_loss: 1.7245
# Epoch 10/100
# 12800/12800 [==============================] - 3s 231us/step - loss: 1.1362 - val_loss: 0.9581
# Epoch 11/100
# 12800/12800 [==============================] - 3s 235us/step - loss: 1.0979 - val_loss: 1.8175
# Epoch 12/100
# 12800/12800 [==============================] - 3s 230us/step - loss: 1.0869 - val_loss: 0.9450
# Epoch 13/100
# 12800/12800 [==============================] - 3s 231us/step - loss: 1.0816 - val_loss: 0.8065
# Epoch 14/100
# 12800/12800 [==============================] - 3s 232us/step - loss: 1.0803 - val_loss: 0.9381
# Epoch 15/100
# 12800/12800 [==============================] - 3s 231us/step - loss: 1.0293 - val_loss: 0.8461
# Epoch 16/100
# 12800/12800 [==============================] - 3s 231us/step - loss: 1.0323 - val_loss: 1.0080
# Epoch 17/100
# 12800/12800 [==============================] - 3s 229us/step - loss: 1.0508 - val_loss: 0.8661
# Epoch 18/100
# 12800/12800 [==============================] - 3s 232us/step - loss: 0.9794 - val_loss: 1.7412
# Epoch 19/100
# 12800/12800 [==============================] - 3s 231us/step - loss: 0.9944 - val_loss: 1.2385
# Epoch 20/100
# 12800/12800 [==============================] - 3s 234us/step - loss: 1.0346 - val_loss: 1.0204
# Epoch 21/100
# 12800/12800 [==============================] - 3s 227us/step - loss: 0.9715 - val_loss: 0.8557
# Epoch 22/100
# 12800/12800 [==============================] - 3s 237us/step - loss: 1.1019 - val_loss: 0.9596
# Epoch 23/100
# 12800/12800 [==============================] - 3s 226us/step - loss: 1.0029 - val_loss: 0.9708
# Epoch 24/100
# 12800/12800 [==============================] - 3s 235us/step - loss: 0.9573 - val_loss: 1.3825
# Epoch 25/100
# 12800/12800 [==============================] - 3s 227us/step - loss: 0.9794 - val_loss: 0.8901
# Epoch 26/100
# 12800/12800 [==============================] - 3s 230us/step - loss: 0.9822 - val_loss: 1.0526
# Epoch 27/100
# 12800/12800 [==============================] - 3s 228us/step - loss: 0.9541 - val_loss: 0.8520
# Epoch 28/100
# 12800/12800 [==============================] - 3s 232us/step - loss: 0.9347 - val_loss: 1.0904
# Epoch 29/100
# 12800/12800 [==============================] - 3s 227us/step - loss: 0.9525 - val_loss: 0.8472
# Epoch 30/100
# 12800/12800 [==============================] - 3s 226us/step - loss: 0.9428 - val_loss: 0.8700
# Epoch 31/100
# 12800/12800 [==============================] - 3s 234us/step - loss: 0.9425 - val_loss: 0.8848
# Epoch 32/100
# 12800/12800 [==============================] - 3s 229us/step - loss: 0.9509 - val_loss: 0.9106
# Epoch 33/100
# 12800/12800 [==============================] - 3s 226us/step - loss: 0.9683 - val_loss: 1.3484
# Epoch 34/100
# 12800/12800 [==============================] - 3s 235us/step - loss: 0.9495 - val_loss: 0.8717
# Epoch 35/100
# 12800/12800 [==============================] - 3s 229us/step - loss: 0.9388 - val_loss: 1.2118
# Epoch 36/100
# 12800/12800 [==============================] - 3s 238us/step - loss: 0.9295 - val_loss: 1.0094
# Epoch 37/100
# 12800/12800 [==============================] - 3s 226us/step - loss: 0.9280 - val_loss: 0.9357
# Epoch 38/100
# 12800/12800 [==============================] - 3s 234us/step - loss: 0.9706 - val_loss: 0.8331
# Epoch 39/100
# 12800/12800 [==============================] - 3s 228us/step - loss: 0.9560 - val_loss: 0.8848
# Epoch 40/100
# 12800/12800 [==============================] - 3s 226us/step - loss: 0.9106 - val_loss: 0.8367
# Epoch 41/100
# 12800/12800 [==============================] - 3s 238us/step - loss: 0.9116 - val_loss: 0.9620
# Epoch 42/100
# 12800/12800 [==============================] - 3s 226us/step - loss: 0.9238 - val_loss: 0.9834
# Epoch 43/100
# 12800/12800 [==============================] - 3s 238us/step - loss: 0.9290 - val_loss: 0.9727
# Epoch 44/100
# 12800/12800 [==============================] - 3s 228us/step - loss: 0.9212 - val_loss: 1.1470
# Epoch 45/100
# 12800/12800 [==============================] - 3s 237us/step - loss: 0.9083 - val_loss: 0.8739
# Epoch 46/100
# 12800/12800 [==============================] - 3s 227us/step - loss: 0.8963 - val_loss: 0.8176
# Epoch 47/100
# 12800/12800 [==============================] - 3s 236us/step - loss: 0.8992 - val_loss: 0.8198
# Epoch 48/100
# 12800/12800 [==============================] - 3s 226us/step - loss: 0.9161 - val_loss: 0.8101
# Epoch 49/100
# 12800/12800 [==============================] - 3s 237us/step - loss: 0.9036 - val_loss: 0.8225
# Epoch 50/100
# 12800/12800 [==============================] - 3s 229us/step - loss: 0.8894 - val_loss: 0.9300
# Epoch 51/100
# 12800/12800 [==============================] - 3s 239us/step - loss: 0.8941 - val_loss: 0.9252
# Epoch 52/100
# 12800/12800 [==============================] - 3s 228us/step - loss: 0.9085 - val_loss: 0.8223
# Epoch 53/100
# 12800/12800 [==============================] - 3s 244us/step - loss: 0.8984 - val_loss: 2.2766
# Epoch 54/100
# 12800/12800 [==============================] - 3s 227us/step - loss: 0.8988 - val_loss: 0.8242
# Epoch 55/100
# 12800/12800 [==============================] - 3s 236us/step - loss: 0.8989 - val_loss: 0.9731
# Epoch 56/100
# 12800/12800 [==============================] - 3s 232us/step - loss: 0.8760 - val_loss: 0.8169
# Epoch 57/100
# 12800/12800 [==============================] - 3s 238us/step - loss: 0.9346 - val_loss: 0.8941
# Epoch 58/100
# 12800/12800 [==============================] - 3s 230us/step - loss: 0.9105 - val_loss: 0.8412
# Epoch 59/100
# 12800/12800 [==============================] - 3s 232us/step - loss: 0.8917 - val_loss: 0.8782
# Epoch 60/100
# 12800/12800 [==============================] - 3s 234us/step - loss: 0.8910 - val_loss: 0.8379
# Epoch 61/100
# 12800/12800 [==============================] - 3s 227us/step - loss: 0.9252 - val_loss: 0.8354
# Epoch 62/100
# 12800/12800 [==============================] - 3s 242us/step - loss: 0.8936 - val_loss: 0.9064
# Epoch 63/100
# 12800/12800 [==============================] - 3s 228us/step - loss: 0.9370 - val_loss: 0.8140
# Epoch 64/100
# 12800/12800 [==============================] - 3s 238us/step - loss: 0.9079 - val_loss: 0.8197
# Epoch 65/100
# 12800/12800 [==============================] - 3s 229us/step - loss: 0.8807 - val_loss: 0.8923
# Epoch 66/100
# 12800/12800 [==============================] - 3s 241us/step - loss: 0.8778 - val_loss: 0.8092
# Epoch 67/100
# 12800/12800 [==============================] - 3s 233us/step - loss: 0.8734 - val_loss: 0.8590
# Epoch 68/100
# 12800/12800 [==============================] - 3s 240us/step - loss: 0.8811 - val_loss: 0.9071
# Epoch 69/100
# 12800/12800 [==============================] - 3s 230us/step - loss: 0.8815 - val_loss: 0.8286
# Epoch 70/100
# 12800/12800 [==============================] - 3s 228us/step - loss: 0.8816 - val_loss: 0.8577
# Epoch 71/100
# 12800/12800 [==============================] - 3s 240us/step - loss: 0.8705 - val_loss: 0.8359
# Epoch 72/100
# 12800/12800 [==============================] - 3s 236us/step - loss: 0.8994 - val_loss: 0.7753
# Epoch 73/100
# 12800/12800 [==============================] - 3s 227us/step - loss: 0.8768 - val_loss: 0.8281
# Epoch 74/100
# 12800/12800 [==============================] - 3s 230us/step - loss: 0.8860 - val_loss: 0.8049
# Epoch 75/100
# 12800/12800 [==============================] - 3s 228us/step - loss: 0.8724 - val_loss: 0.8027
# Epoch 76/100
# 12800/12800 [==============================] - 3s 228us/step - loss: 0.8994 - val_loss: 0.8451
# Epoch 77/100
# 12800/12800 [==============================] - 3s 228us/step - loss: 0.8747 - val_loss: 0.8559
# Epoch 78/100
# 12800/12800 [==============================] - 3s 228us/step - loss: 0.8956 - val_loss: 1.1520
# Epoch 79/100
# 12800/12800 [==============================] - 3s 228us/step - loss: 0.8935 - val_loss: 0.9793
# Epoch 80/100
# 12800/12800 [==============================] - 3s 229us/step - loss: 0.8689 - val_loss: 0.8567
# Epoch 81/100
# 12800/12800 [==============================] - 3s 227us/step - loss: 0.8813 - val_loss: 0.8587
# Epoch 82/100
# 12800/12800 [==============================] - 3s 227us/step - loss: 0.8634 - val_loss: 0.8149
# Epoch 83/100
# 12800/12800 [==============================] - 3s 227us/step - loss: 0.8807 - val_loss: 0.8232
# Epoch 84/100
# 12800/12800 [==============================] - 3s 227us/step - loss: 0.8379 - val_loss: 0.7901
# Epoch 85/100
# 12800/12800 [==============================] - 3s 230us/step - loss: 0.9360 - val_loss: 0.9032
# Epoch 86/100
# 12800/12800 [==============================] - 3s 228us/step - loss: 0.8857 - val_loss: 0.9515
# Epoch 87/100
# 12800/12800 [==============================] - 3s 229us/step - loss: 0.8985 - val_loss: 0.8322
# Epoch 88/100
# 12800/12800 [==============================] - 3s 235us/step - loss: 0.8900 - val_loss: 0.8149
# Epoch 89/100
# 12800/12800 [==============================] - 3s 231us/step - loss: 0.8750 - val_loss: 1.5727
# Epoch 90/100
# 12800/12800 [==============================] - 3s 228us/step - loss: 0.8972 - val_loss: 0.8772
# Epoch 91/100
# 12800/12800 [==============================] - 3s 227us/step - loss: 0.9065 - val_loss: 1.0472
# Epoch 92/100
# 12800/12800 [==============================] - 3s 228us/step - loss: 0.8847 - val_loss: 0.7991
# Epoch 93/100
# 12800/12800 [==============================] - 3s 227us/step - loss: 0.8522 - val_loss: 0.8599
# Epoch 94/100
# 12800/12800 [==============================] - 3s 229us/step - loss: 0.8614 - val_loss: 0.8410
# Epoch 95/100
# 12800/12800 [==============================] - 3s 229us/step - loss: 0.8718 - val_loss: 0.8243
# Epoch 96/100
# 12800/12800 [==============================] - 3s 228us/step - loss: 0.8865 - val_loss: 0.8443
# Epoch 97/100
# 12800/12800 [==============================] - 3s 228us/step - loss: 0.8696 - val_loss: 1.0482
# Epoch 98/100
# 12800/12800 [==============================] - 3s 228us/step - loss: 0.8600 - val_loss: 0.9820
# Epoch 99/100
# 12800/12800 [==============================] - 3s 228us/step - loss: 0.8650 - val_loss: 0.8206
# Epoch 100/100
# 12800/12800 [==============================] - 3s 227us/step - loss: 0.8661 - val_loss: 0.9431

# %%
cd ..
# Out:
# /content/drive/My Drive/concrete_crack

# %%
os.mkdir('model8')

# %%
cd model8/
# Out:
# /content/drive/My Drive/concrete_crack/model8

# %%
save_model(encoder,filepath='encoder.h5')
save_model(decoder,filepath='decoder.h5')
save_model(autoencoder,filepath='autoencoder.h5')

# %%
np.save('model1_history', history.history, allow_pickle=True)

# %%
np.save('training_loss', history.history['loss'], allow_pickle=True)
np.save('validation_loss', history.history['val_loss'], allow_pickle=True)

# %%
plt.plot(np.load('training_loss.npy', allow_pickle=True))
